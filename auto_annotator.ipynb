# %%
import requests
import json
import csv
import time
from urllib.parse import urlparse
import os
import string
import matplotlib.pyplot as plt

# %%
csv_output_file = './data/crawl/tiktok_comments.csv'
labeled_csv_output_file = './data/crawl/tiktok_comments_labeled.csv'
repaired_csv = './data/crawl/tiktok_comments_clean.csv'

# %%
def label_emotion_with_lmstudio(text):
    """
    Phân loại cảm xúc văn bản tiếng Việt dùng LM Studio (local LLM) chỉ dựa trên text và teen code
    0: Vui vẻ, 1: Tức giận, 2: Buồn, 3: Sợ hãi, 4: Trung lập
    """
    try:
        # Validate input
        if not text or not isinstance(text, str):
            print("⚠️ Input không hợp lệ")
            return 4

        # Từ điển teen code phổ biến và cảm xúc tương ứng
        teen_code_dict = {
            # Vui vẻ
            "vk": 0, "vler": 0, "qtqd": 0, "ckđ": 0, "hehe": 0, "hihi": 0, "vcl": 0, "vl": 0,
            # Tức giận
            "dm": 1, "dmm": 1, "clm": 1, "clmm": 1, "dkm": 1, "dkmm": 1, "dcm": 1, "dcmm": 1, "lạy": 1,
            # Buồn
            "tđn": 2, "sml": 2, "cc": 2, "oz": 2, "tđb": 2, "tđx": 2,
            # sợ hãi
            "hãi": 3, "hú hồn": 3, "vl": 3, "bay màu": 3, "vãi đạn": 3
        }

        # Kiểm tra teen code (chuyển sang chữ thường để so sánh)
        lower_text = text.lower().strip()
        if lower_text in teen_code_dict:
            return teen_code_dict[lower_text]

        # Optimized prompt chỉ tập trung vào text và teen code
        prompt = """Bạn là chuyên gia phân loại cảm xúc và Hãy phân loại cảm xúc của 1 đoạn comment TIẾNG VIỆT sau thành 1 trong 5 số (chỉ dựa trên văn bản):
0: Vui vẻ - niềm vui, hạnh phúc, tích cực
   • Teen code: vk, vler, qtqd, ckđ, hehe, hihi
   VD: "Thật tuyệt vời", "Hôm nay là một ngày vui", "vk quá đi"
1: Tức giận - giận dữ, khó chịu, bực bội
   • Teen code: dm, dmm, clm, dkm
   VD: "Đồ ngu ngốc!", "Tao cực kỳ tức giận", "clm mày"
2: Buồn - nỗi buồn, thất vọng, đau khổ
   • Teen code: tđn, sml, oz, tđb
   VD: "Cuộc sống thật chán", "Hôm nay buồn quá", "sml rồi"
3: sợ hãi - lo âu (cảm xúc mà con người cảm nhận được khi cảm thấy mối đe doạ, nguy hiểm hoặc rủi ro, dù thật hay tưởng tượng)
   • Teen code: hãi vl, hú hồn chim én, sợ vl, thấy mà sợ
   VD: "Nghe kể chuyện ma xong mà sợ vl luôn á", "Nhìn cái mặt ông thầy lúc gọi tên tui mà hãi vl", "Đang yên đang lành tự nhiên hiện cái mặt đó lên, thấy mà sợ vl luôn" ...
4: Trung lập - không cảm xúc rõ ràng
   VD: "Hôm nay trời mưa", "Tôi đi làm lúc 8 giờ", "Đây là thông tin khách quan"

Bình luận cần phân loại: "{}"
→ Chỉ trả về 1 số từ 0-4, không giải thích:""".format(text)

        payload = {
            "messages": [{"role": "user", "content": prompt}],
            "temperature": 0.3,
            "max_tokens": 1,
            "stop": ["\n"]
        }

        # Gọi API LM Studio
        response = requests.post(
            "http://localhost:1234/v1/chat/completions",
            headers={'Content-Type': 'application/json'},
            json=payload,
            timeout=600
        )

        # Xử lý response
        response.raise_for_status()
        result = response.json()
        
        # Lấy kết quả (đảm bảo chỉ lấy số)
        output = result["choices"][0]["message"]["content"].strip()
        
        if output.isdigit() and 0 <= int(output) <= 4:
            return int(output)
            
        print(f"⚠️ Kết quả không hợp lệ: '{output}' cho: '{text[:30]}...'")
        return 4
    
    except requests.exceptions.RequestException as e:
        print(f"❌ Lỗi kết nối LM Studio: '{text[:30]}...' | Lỗi: {str(e)}")
        return 4
    except Exception as e:
        print(f"❌ Lỗi xử lý: '{text[:30]}...' | Lỗi: {type(e).__name__}: {str(e)}")
        return 4

# %%
def label_and_export_comments(input_csv_file, output_csv_file, checkpoint_interval=10):
    import csv, os, time

    labeled_comments = []
    processed_lines = set()

    # Nếu file output đã tồn tại, đọc các dòng đã xử lý
    if os.path.exists(output_csv_file):
        with open(output_csv_file, 'r', encoding='utf-8') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                if 'line_number' in row:
                    processed_lines.add(int(row['line_number']))

    print(f"🔄 Tiếp tục gán nhãn. Đã gán: {len(processed_lines)} comments")

    try:
        with open(input_csv_file, 'r', encoding='utf-8') as csvfile:
            all_lines = list(csvfile.readlines())

        header = all_lines[0].strip().split(',')  # get column names
        reader = csv.DictReader(all_lines[1:], fieldnames=header)
        batch = []

        for line_number, row in enumerate(reader, start=2):  # start=2 vì dòng 1 là header
            if line_number in processed_lines:
                continue

            text = row.get('text', '').strip()
            if not text:
                continue

            # Gán nhãn cảm xúc
            emotion_label = label_emotion_with_lmstudio(text)
            labeled_comment = {
                'line_number': line_number,
                'text': text,
                'emotion_label': emotion_label
            }

            batch.append(labeled_comment)
            processed_lines.add(line_number)

            print(f"Line {line_number} | Labeled: {text[:50]}... → {emotion_label}")

            # Lưu checkpoint
            if len(batch) >= checkpoint_interval:
                save_to_csv(output_csv_file, batch)
                print(f"💾 Checkpoint saved {len(batch)} comments (Total: {len(processed_lines)})")
                batch.clear()

            time.sleep(3)  # tránh bị rate limit

        # Lưu phần còn lại
        if batch:
            save_to_csv(output_csv_file, batch)
            print(f"✅ Final save {len(batch)} comments (Total: {len(processed_lines)})")

    except Exception as e:
        print(f"\n❌ Error during labeling: {str(e)}")


def save_to_csv(file_path, data, fieldnames=['line_number', 'text', 'emotion_label']):
    file_exists = os.path.exists(file_path)
    with open(file_path, 'a', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        if not file_exists:
            writer.writeheader()
        writer.writerows(data)

# %% [markdown]
# ### Phân loại cảm xúc
# 0: Vui vẻ, 1: Tức giận, 2: Buồn bã, 3: Sợ hãi, 4: Trung lập.

# %%
label_and_export_comments(csv_output_file, labeled_csv_output_file, checkpoint_interval=5)
# Out:
# 🔄 Tiếp tục gán nhãn. Đã gán: 28521 comments
# Line 28523 | Labeled: @sendeptraimedeku0912 tao tưởng boom:^... → 1
# Line 28524 | Labeled: 🥺🥺🥺... → 2
# Line 28525 | Labeled: @luciavong... → 4
# Line 28526 | Labeled: Amen... → 4
# Line 28527 | Labeled: @gauheoe coi nè e... → 4
# 💾 Checkpoint saved 5 comments (Total: 28526)
# Line 28528 | Labeled: nổ ga như bom 🥺🥺... → 0
# Line 28529 | Labeled: @phongcon25 nổi da gà... → 3
# Line 28530 | Labeled: Sao cứu hoả lâu đến thế ạ 😢😢... → 2
# Line 28531 | Labeled: @mduy.1802... → 4
# Line 28532 | Labeled: A DI ĐÀ PHẬT... → 4
# 💾 Checkpoint saved 5 comments (Total: 28531)
# Line 28533 | Labeled: tội cái khách sạn😂... → 2
# Line 28534 | Labeled: @kimhangto99... → 4
# Line 28535 | Labeled: ôi khổ quá... → 2
# Line 28536 | Labeled: 😞😞😞😞😞😞... → 2
# Line 28537 | Labeled: Bình gas k đạt tiêu chuẩn mới nổ... → 3
# 💾 Checkpoint saved 5 comments (Total: 28536)
# Line 28538 | Labeled: cái FPT kế bên luôn... → 4
# Line 28539 | Labeled: NHÀ GAS CHÁY LÀM CHÁY NHỮNG CHỖ KẾ BÊN... có đền h... → 2
# Line 28540 | Labeled: nam mô a di đà phật... → 4
# Line 28541 | Labeled: o sa pa... → 4
# Line 28542 | Labeled: @hmyyaww... → 4
# 💾 Checkpoint saved 5 comments (Total: 28541)
# Line 28543 | Labeled: @alice_pham52... → 4
# Line 28544 | Labeled: @linhbui201294... → 4
# Line 28545 | Labeled: không biết có ai làm sao không... → 2
# Line 28546 | Labeled: Hồi hộp như xem bắn pháo hoa... → 0
# Line 28547 | Labeled: những tình huống thế này hãy đổ nước vào 😂... → 0
# 💾 Checkpoint saved 5 comments (Total: 28546)
# Line 28548 | Labeled: bọn cứ hoả chết cháy hết rồi à... → 1
# Line 28549 | Labeled: nổ bình gas mini... → 4
# Line 28550 | Labeled: có phải đền bù 2 nhà bên cạnh k nhỉ😬... → 4
# Line 28551 | Labeled: này nãy trên 60s có nè... → 4
# Line 28552 | Labeled: ko kêu cứu hỏa mn ơi... → 4
# 💾 Checkpoint saved 5 comments (Total: 28551)
# Line 28553 | Labeled: đm nghe xe cứu hỏa chạy mà hết video ko thấy... → 1
# Line 28554 | Labeled: @sonylee18... → 4
# Line 28555 | Labeled: Ở Thị trấn Sa Pa này! Ngay chỗ chợ đêm Sa Pa luôn!... → 2
# Line 28556 | Labeled: Xem chỉ sợ nó cháy sang qua nhà bên kia😕... → 3
# Line 28557 | Labeled: Cháy to quá... → 1
# 💾 Checkpoint saved 5 comments (Total: 28556)
# Line 28558 | Labeled: có đóng tiền chữa cháy hàng tháng chưa mà đội PCCC... → 1
# Line 28559 | Labeled: ở đâu vậy chủ thớt... → 4
# Line 28560 | Labeled: @dungdang713... → 4
# Line 28561 | Labeled: ngay cạnh cái khách sạn không biết mấy người đó ch... → 3
# Line 28562 | Labeled: Sơ quá... → 2
# 💾 Checkpoint saved 5 comments (Total: 28561)
# Line 28563 | Labeled: cho hỏi ở đâu vậy... → 4
# Line 28564 | Labeled: Cháy thế chưa cắt điện ai dám phun , nhà bán ga gi... → 1
# Line 28565 | Labeled: nhạc chill dễ ngủ... → 4
# Line 28566 | Labeled: mình dag là nhân viên giao Gas, mé thấy cảnh này k... → 3
# Line 28567 | Labeled: Tui ngồi xem đi xem lại cả tiếng rồi mà chưa thấy ... → 3
# 💾 Checkpoint saved 5 comments (Total: 28566)
# Line 28568 | Labeled: hm nào vậy bạn... → 4
# Line 28569 | Labeled: Nhà có 4 đứa con thì an toàn hết nha. Chỉ chậm 15s... → 3
# Line 28570 | Labeled: Buồn thế nhở... → 2
# Line 28571 | Labeled: tiếng hét như con gái thế anh... → 1
# Line 28572 | Labeled: adidaphat... → 4
# 💾 Checkpoint saved 5 comments (Total: 28571)
# Line 28573 | Labeled: @dy5lsumtdmrm pháo hoa sợ... → 3
# Line 28574 | Labeled: @chanhselcouth khúc cuối nổ cái giật mình luôn... → 3
# Line 28575 | Labeled: Vụ cháy này ở đâu vậy mọi người ?... → 4
# Line 28576 | Labeled: ở đâu vậy em ơi... → 4
# Line 28577 | Labeled: @haiquayxe2302... → 4
# 💾 Checkpoint saved 5 comments (Total: 28576)
# Line 28578 | Labeled: @hocban96... → 4
# Line 28579 | Labeled: đền tiền ốm ng... → 2
# Line 28580 | Labeled: Phương@phuongpphuong... → 4
# Line 28581 | Labeled: @nlyn11125... → 4
# Line 28582 | Labeled: hàng xóm có khác 😂😂... → 0
# 💾 Checkpoint saved 5 comments (Total: 28581)
# Line 28583 | Labeled: 싸이렌소리만 엄청나고 길에 불법주차도 없는데 소방차는 안오고 다 탓네 한국이 아니길 다행이... → 4
# Line 28584 | Labeled: @an2806022... → 4
# Line 28585 | Labeled: thì ra ông này là ng quay này tui thấy tin này trê... → 0
# Line 28586 | Labeled: Mong gia đình bình an... → 0
# Line 28587 | Labeled: phố nào... → 4
# 💾 Checkpoint saved 5 comments (Total: 28586)
# Line 28588 | Labeled: ở đâu vậy... → 4
# Line 28589 | Labeled: @kim_oanh_2709... → 4
# Line 28590 | Labeled: cái này điện lực k cắt điện thì chưa hỏa có đó cũn... → 1
# Line 28591 | Labeled: ủa cái này ở đâu vậy bạn🥺... → 4
# Line 28592 | Labeled: mấy nhà bên cạnh kiểu :)))))... → 0
# 💾 Checkpoint saved 5 comments (Total: 28591)
# Line 28593 | Labeled: May mà k thiệt hại về người... → 4
# Line 28594 | Labeled: gê😬... → 3
# Line 28595 | Labeled: thiệt hại r... → 2
# Line 28596 | Labeled: khách sạn mây hồ kiểu:má đen thùi lùi cái mặt tiền... → 1
# Line 28597 | Labeled: đám cưới này được 1 năm rùi mà giờ nữa hả... → 2
# 💾 Checkpoint saved 5 comments (Total: 28596)
# Line 28598 | Labeled: Nhìn sợ ghê... → 3
# Line 28599 | Labeled: cháy nhà bán ga mới ác chứ... → 1
# Line 28600 | Labeled: Bắn pháo hoa sớm hã ta :v... → 0
# Line 28601 | Labeled: Nhà bán ga giờ đền tiền 2 nhà kia bể nợ😅... → 2
# Line 28602 | Labeled: Gas mini dùng cho bếp lẩu à b. Chứ bình gas 12kg t... → 1
# 💾 Checkpoint saved 5 comments (Total: 28601)
# Line 28603 | Labeled: biết nè hâhha... → 0
# Line 28604 | Labeled: 2 nhà hàng xóm ko cháy ảo thặc đấy... → 4
# Line 28605 | Labeled: Nam mô a di đà phật... → 4
# Line 28606 | Labeled: Ở đâu vậy ạ... → 4
# Line 28607 | Labeled: @vanduke3 gê... → 0
# 💾 Checkpoint saved 5 comments (Total: 28606)
# Line 28608 | Labeled: Xin được lắng nghe các chuyên gia phòng, cháy chữa... → 0
# Line 28609 | Labeled: Híu mãi sôt ruộ... → 0
# Line 28610 | Labeled: có bao hiem chay nổ cung đở dc phần nào... → 4
# Line 28611 | Labeled: ở đâu đây ah?... → 4
# Line 28612 | Labeled: cháy luôn cả cái xe máy luôn... → 3
# 💾 Checkpoint saved 5 comments (Total: 28611)
# Line 28613 | Labeled: mấy cái nhà bên cạnh sao không chạy đi đứng đấy nó... → 1
# Line 28614 | Labeled: Ở đâu đây ạ... → 4
# Line 28615 | Labeled: @thanhsuong3 hôm nay e hỏi c bình ga nổ như thế nà... → 3
# Line 28616 | Labeled: @_tnyk2509_ nhìn sợ vc... → 3
# Line 28617 | Labeled: @nt2509_04... → 4
# 💾 Checkpoint saved 5 comments (Total: 28616)
# Line 28618 | Labeled: xe cứu hoả đứng nhìn à 😁... → 1
# Line 28619 | Labeled: @mandoo_293 @duyeenmunnef... → 4
# Line 28620 | Labeled: Cứu hỏa rú còi mà chẳng thay là sao... → 1
# Line 28621 | Labeled: Sợ thật😳... → 3
# Line 28622 | Labeled: @anh_van1995  ghê qu... → 1
# 💾 Checkpoint saved 5 comments (Total: 28621)
# Line 28623 | Labeled: sao k gọu cứu hoả ạ... → 3
# Line 28624 | Labeled: dịch vậy là Trắng tay😌... → 2
# Line 28625 | Labeled: @tranngoclua troi... → 4
# Line 28626 | Labeled: @koolkoolkool4 coi ghê ko nè... → 3
# Line 28627 | Labeled: nghe giọng bn gái nhìn quen quen... → 4
# 💾 Checkpoint saved 5 comments (Total: 28626)
# Line 28628 | Labeled: @tu0108... → 4
# Line 28629 | Labeled: Cúp điện chưa huy hiểm quá à... → 3
# Line 28630 | Labeled: @thanhliens 😳😳😳... → 4
# Line 28631 | Labeled: Bình 12kg khi có tác động mạnh đốt nóng hoặc rơi t... → 4
# Line 28632 | Labeled: trên có vid y chang trùng hợp😳... → 4
# 💾 Checkpoint saved 5 comments (Total: 28631)
# Line 28633 | Labeled: @quynh_1231234... → 4
# Line 28634 | Labeled: Ms thấy bên face... → 4
# Line 28635 | Labeled: @lilackhac... → 4
# Line 28636 | Labeled: @trungnhat1911... → 4
# Line 28637 | Labeled: nghe nổ như pháo hoa ngày tết😅... → 0
# 💾 Checkpoint saved 5 comments (Total: 28636)
# Line 28638 | Labeled: đợi xe cứu tới cháy tàng luôn r... → 3
# Line 28639 | Labeled: 🥺🥺🥺🥺🥺... → 2
# Line 28640 | Labeled: @hunglacuatubabycute... → 4
# Line 28641 | Labeled: người không sao là may rồi . Còn người là còn của ... → 2
# Line 28642 | Labeled: éo nha e nấu ko bh đóng van chứ... → 1
# 💾 Checkpoint saved 5 comments (Total: 28641)
# Line 28643 | Labeled: Thương chủ nhà quá,nghèo luôn rồi thêm đền mấy nhà... → 2
# Line 28644 | Labeled: Vừa đọc đc bài này có 1ng xưng là bạn kêu gọi mn ủ... → 4
# Line 28645 | Labeled: 🧯💦🔥... → 4
# Line 28646 | Labeled: @huynhnhhnnhu... → 4
# Line 28647 | Labeled: thằng quay video điệu thế... → 1
# 💾 Checkpoint saved 5 comments (Total: 28646)
# Line 28648 | Labeled: Cháy ở đâu vậy b?... → 4
# Line 28649 | Labeled: ui sợ thế sợ vl... → 3
# Line 28650 | Labeled: @phuonghoanghai... → 4
# Line 28651 | Labeled: Ở sapa đk ạ... → 0
# Line 28652 | Labeled: sợ thật... → 3
# 💾 Checkpoint saved 5 comments (Total: 28651)
# Line 28653 | Labeled: mẹ cứu hỏa đâu hết rồi. mà kg đến vậy nhỉ... → 2
# Line 28654 | Labeled: Đường Điên Biên Phủ - Sapa đúng kh ah... → 4
# Line 28655 | Labeled: @mikkhank vch... → 1
# Line 28656 | Labeled: có biết nguyên nhân sao bị cháy vậy k ạ khổ bị đ... → 4
# Line 28657 | Labeled: nguy hiểm quá... → 3
# 💾 Checkpoint saved 5 comments (Total: 28656)
# Line 28658 | Labeled: @yn_nhiee99... → 4
# Line 28659 | Labeled: hôm nay e đi qua, hoảng luôn😳... → 3
# Line 28660 | Labeled: Cháy xong mới thấy cứu hoả quá :(... → 2
# Line 28661 | Labeled: @chin14926... → 4
# Line 28662 | Labeled: Trời ơi đã khổ càng thêm khổ nửa 😢... → 2
# 💾 Checkpoint saved 5 comments (Total: 28661)
# Line 28663 | Labeled: @thutyty92... → 4
# Line 28664 | Labeled: Nó cháy dạy điện kìa... → 3
# Line 28665 | Labeled: Dich này mấy a cứu hoa ngủ roi nha bạn.khi nao ch... → 0
# Line 28666 | Labeled: @tranvanhai2872... → 4
# Line 28667 | Labeled: Bảnh có thể múa quạt dập đám cháy nhưng bảnh trong... → 2
# 💾 Checkpoint saved 5 comments (Total: 28666)
# Line 28668 | Labeled: Nổ bình ga kêu phun nước :)... → 0
# Line 28669 | Labeled: @anhduong_n_ vl soẹ thế... → 1
# Line 28670 | Labeled: @ying_deng sợ chưa... → 3
# Line 28671 | Labeled: cảnh này ở sapa thì phải... → 4
# Line 28672 | Labeled: nhanh chí mua xúc xích xg chạy ra nướng... → 0
# 💾 Checkpoint saved 5 comments (Total: 28671)
# Line 28673 | Labeled: nổ ga ghê vậy... → 3
# Line 28674 | Labeled: @nayoen1995... → 4
# Line 28675 | Labeled: Sa pa... → 4
# Line 28676 | Labeled: Của cải tiêu tan trong phút chốc 🥺. Mai là ng an t... → 2
# Line 28677 | Labeled: @user710661041... → 4
# 💾 Checkpoint saved 5 comments (Total: 28676)
# Line 28678 | Labeled: Nghe như bắn pháo hoa ý... → 0
# Line 28679 | Labeled: khác gì bom... → 3
# Line 28680 | Labeled: y như bắn pháo hoa á ta😳😳... → 0
# Line 28681 | Labeled: ghe quá... → 2
# Line 28682 | Labeled: khách sạn Mây Hồ hén, hô theo Lông Anh đồ...... → 4
# 💾 Checkpoint saved 5 comments (Total: 28681)
# Line 28683 | Labeled: @kimtien2503... → 4
# Line 28684 | Labeled: 2 khách sạn kiểu ở giữa là kho chứa bom nó sẽ cháy... → 3
# Line 28685 | Labeled: Mấy ông đi hotel hôm đó xui... → 4
# Line 28686 | Labeled: nãy coi thời sự thaya... → 4
# Line 28687 | Labeled: cứ thấy có cháy là vào xem có ai bị kẹt ko? Mà thư... → 0
# 💾 Checkpoint saved 5 comments (Total: 28686)
# Line 28688 | Labeled: 🥺🥺🥺🥺 đã dịch đói khổ lại còn cháy tội nghiệp a chủ... → 2
# Line 28689 | Labeled: ở đâu vậy bạn ơi... → 4
# Line 28690 | Labeled: vừa mới xem trên fb. vô đậy lại thấy 😞😞... → 2
# Line 28691 | Labeled: @tecutenhat sow... → 0
# Line 28692 | Labeled: ở đou đây ạ... → 4
# 💾 Checkpoint saved 5 comments (Total: 28691)
# Line 28693 | Labeled: VN cứu hỏa à khi nào cháy hết nó mới đến nơi... → 1
# Line 28694 | Labeled: đâg nấu cơm😅... → 0
# Line 28695 | Labeled: @nhung200211... → 4
# Line 28696 | Labeled: nổ ở đâu vậy... → 4
# Line 28697 | Labeled: tội khách sạn kế bên😂😂... → 0
# 💾 Checkpoint saved 5 comments (Total: 28696)
# Line 28698 | Labeled: Khổ quá. Đen... → 2
# Line 28699 | Labeled: @user037797570... → 4
# Line 28700 | Labeled: @onii.chan3ka dịch mà còn zầy thì thôi... → 1
# Line 28701 | Labeled: đẹp qué... → 0
# Line 28702 | Labeled: đây có phải ở rừng thông thanh hóa không vậy bạn... → 4
# 💾 Checkpoint saved 5 comments (Total: 28701)
# Line 28703 | Labeled: fpt kiểu: nam mô a di đà phật... → 4
# Line 28704 | Labeled: Og CA PCCC hôm trước to mồm bảo là gọi thì có mặt ... → 1
# Line 28705 | Labeled: mấy đứa trong khách sạn kiểu sao hôm nay nóng thế ... → 0
# Line 28706 | Labeled: @yenhi2605... → 4
# Line 28707 | Labeled: @tuilaneesociu... → 4
# 💾 Checkpoint saved 5 comments (Total: 28706)
# Line 28708 | Labeled: Nam mô a di đà phật câu cho cô chu mau chống bình ... → 4
# Line 28709 | Labeled: Ở đâu vậy bạn 😞... → 2
# Line 28710 | Labeled: ga dập bằng nước :((... → 2
# Line 28711 | Labeled: dịch đã khổ rồi lại thêm cháy nữa khổ quá mà... → 2
# Line 28712 | Labeled: chồnng mình cũng làm bên pccc. mỗi lần đi làm nhiệ... → 2
# 💾 Checkpoint saved 5 comments (Total: 28711)
# Line 28713 | Labeled: @jena1909 @bichtram.pn96... → 4
# Line 28714 | Labeled: Khổ nhà bên cạnh... → 2
# Line 28715 | Labeled: chán chả muốn nói. 😏... → 2
# Line 28716 | Labeled: @phan_thao22... → 4
# Line 28717 | Labeled: @nguyenlinh2515 🥺🥺... → 0
# 💾 Checkpoint saved 5 comments (Total: 28716)
# Line 28718 | Labeled: ở gần mấy ôg bán ga cũg sợ như gần kho bom vậy. bả... → 3
# Line 28719 | Labeled: cảm ơn trời đất, mong cả nhà khoẻ mạnh 🥺... → 0
# Line 28720 | Labeled: @bon9000k sợ vãi... → 3
# Line 28721 | Labeled: Cho mình hỏi ơi đâu đc kh ạ... → 4
# Line 28722 | Labeled: lên tivi luôn... → 0
# 💾 Checkpoint saved 5 comments (Total: 28721)
# Line 28723 | Labeled: hãi quá may không có ai... → 3
# Line 28724 | Labeled: Ở sapa này 😬😬... → 4
# Line 28725 | Labeled: Sao k dắt mấy cái xe máy ra xa tí nhỉ... → 4
# Line 28726 | Labeled: cứu hoả tâm 2 tiếng nữa... → 3
# Line 28727 | Labeled: sợ quá... → 3
# 💾 Checkpoint saved 5 comments (Total: 28726)
# Line 28728 | Labeled: Nghe tiếng hú mà hok thấy đâu... → 3
# Line 28729 | Labeled: ở đâu đây ạ... → 4
# Line 28730 | Labeled: Còn gì nữa đâu 🥲😥... → 2
# Line 28731 | Labeled: Đây là ở Sapa lào caiii🥺... → 2
# Line 28732 | Labeled: mấy thằng cứu hỏa đứng nhìn ah... → 1
# 💾 Checkpoint saved 5 comments (Total: 28731)
# Line 28733 | Labeled: nhà này làm ảnh hưởng đến nhà bên cạnh... → 1
# Line 28734 | Labeled: @roberttini90... → 4
# Line 28735 | Labeled: Ly do chay vậy vậy anh , bởi vậy tất cả chúng ta k... → 4
# Line 28736 | Labeled: lạy mấy ba mấy má. làm như cứu hoả gần như nhà mấy... → 1
# Line 28737 | Labeled: chưa tết mà mấy bác😂... → 4
# 💾 Checkpoint saved 5 comments (Total: 28736)
# Line 28738 | Labeled: Nghe giọng bạn trai là biết cưng dễ sợ r nhá 🥰... → 0
# Line 28739 | Labeled: ở đâu vậy ak... → 4
# Line 28740 | Labeled: @tranducanh3101... → 4
# Line 28741 | Labeled: @tuananh99995555... → 4
# Line 28742 | Labeled: chỗ nào nhỉ... → 4
# 💾 Checkpoint saved 5 comments (Total: 28741)
# Line 28743 | Labeled: Ở đâu vậy ad... → 4
# Line 28744 | Labeled: @ngphuongthao007... → 4
# Line 28745 | Labeled: Ở SaPa chỗ tui nè :))... → 0
# Line 28746 | Labeled: Nam Mô A Di Đà Phật. May mà người cứu được... → 0
# Line 28747 | Labeled: ngay nhà pà ngoại mình:(... → 2
# 💾 Checkpoint saved 5 comments (Total: 28746)
# Line 28748 | Labeled: ờ đâu vậy bạn... → 4
# Line 28749 | Labeled: Ở đâu đấy chủ thớt... → 4
# Line 28750 | Labeled: Cứu hoa buồn ngủ hay gi ma lâu v... → 2
# Line 28751 | Labeled: đúng là ks mây... → 4
# Line 28752 | Labeled: đéo có xe cứu hỏa... → 2
# 💾 Checkpoint saved 5 comments (Total: 28751)
# Line 28753 | Labeled: Xem hốt quá ma nghe mấy acj thuyết minh bình luận ... → 4
# Line 28754 | Labeled: @trinhbi123... → 4
# Line 28755 | Labeled: t bấm dừng lại rồi đó ai muốn cứu gì vô cứu đi... → 1
# Line 28756 | Labeled: vụ này ở đâu vậy bạn... → 4
# Line 28757 | Labeled: noi nhieu the sao ko goi... → 2
# 💾 Checkpoint saved 5 comments (Total: 28756)
# Line 28758 | Labeled: o dau the cac bac... → 4
# Line 28759 | Labeled: cứu dk người là may mắn rồi.... → 0
# Line 28760 | Labeled: ở đâu vậy bạn... → 4
# Line 28761 | Labeled: @vutuyet040806 😳... → 4
# Line 28762 | Labeled: ở đâu vậy ạ... → 4
# 💾 Checkpoint saved 5 comments (Total: 28761)
# Line 28763 | Labeled: ko sao ko sao chúa phù hộ cho họ 🥺🥺... → 0
# Line 28764 | Labeled: uầy 2 cái khách sạn bên cạnh kìa... → 4
# Line 28765 | Labeled: lấy xăng dô dập lửa 😂... → 0
# Line 28766 | Labeled: o đâu vậy ạ... → 4
# Line 28767 | Labeled: Kiểu nhà bạn đã bán gas bạn còn nghiện thuốc 😂... → 1
# 💾 Checkpoint saved 5 comments (Total: 28766)
# Line 28768 | Labeled: êu đã dịch lại còn 🥺... → 2
# Line 28769 | Labeled: phần tiếp xe chữa cháy đi... → 4
# Line 28770 | Labeled: A du... → 4
# Line 28771 | Labeled: @ddg2910 uầy đm... → 1
# Line 28772 | Labeled: nguy hiểm quá... → 3
# 💾 Checkpoint saved 5 comments (Total: 28771)
# Line 28773 | Labeled: @longg2kar7 ghê ha🙄... → 4
# Line 28774 | Labeled: @hak0610... → 4
# Line 28775 | Labeled: vãi cả lo* mẹ kêu "gọi cho điện tắt điện ngay" đứa... → 1
# Line 28776 | Labeled: ở đâu vậy nhìn giống như ở sa pa vậy... → 4
# Line 28777 | Labeled: ối dồi ôi... → 0
# 💾 Checkpoint saved 5 comments (Total: 28776)
# Line 28778 | Labeled: @thuthao28_02... → 4
# Line 28779 | Labeled: K múc nước chạy ra. Đứng quay vậy chời.... → 4
# Line 28780 | Labeled: @tumottoitam ghê m... → 2
# Line 28781 | Labeled: @tminhh201... → 4
# Line 28782 | Labeled: @namnho19999... → 4
# 💾 Checkpoint saved 5 comments (Total: 28781)
# Line 28783 | Labeled: ms thấy trên ts chiều... → 4
# Line 28784 | Labeled: Số ng ghét cái câu: không liên quan đến nhà mình =... → 1
# Line 28785 | Labeled: Lạy trời... → 2
# Line 28786 | Labeled: ở đâu vậy bạn?... → 4
# Line 28787 | Labeled: sợ thế đây là ở đâu đấy bạn ơi... → 3
# 💾 Checkpoint saved 5 comments (Total: 28786)
# Line 28788 | Labeled: Vc bìu... → 1
# Line 28789 | Labeled: @tuyetshyn.145 qua xem cái này xong đi ngủ bạn ơii... → 4
# Line 28790 | Labeled: sợ quá đi mất... → 3
# Line 28791 | Labeled: @harunehihi ê m vào m lướt cmt xem chú chủ nhà bị ... → 3
# Line 28792 | Labeled: Chỗ cháy này ở đâu vậy mn... → 4
# 💾 Checkpoint saved 5 comments (Total: 28791)
# Line 28793 | Labeled: ở đâu vậy... → 4
# Line 28794 | Labeled: may k thiệt hại về người 🙏🙏🙏... → 3
# Line 28795 | Labeled: sapa đúng ko ạ🥺... → 2
# Line 28796 | Labeled: trời ơi sợ quá 😭😭... → 3
# Line 28797 | Labeled: ở đâu vậy b.... → 4
# 💾 Checkpoint saved 5 comments (Total: 28796)
# Line 28798 | Labeled: Cháy o dau vay b... → 4
# Line 28799 | Labeled: cái xe cháy oan... → 2
# Line 28800 | Labeled: Sợ quá... → 3
# Line 28801 | Labeled: @dungtrang1696... → 4
# Line 28802 | Labeled: nguyên nhân tại sao cháy nổ vậy bạn... → 4
# 💾 Checkpoint saved 5 comments (Total: 28801)
# Line 28803 | Labeled: sợ quá... → 3
# Line 28804 | Labeled: @tieuyeu_204... → 4
# Line 28805 | Labeled: @237096tl... → 4
# Line 28806 | Labeled: sao này nhà tụi cháy.ngtak cũng quay như vậy... → 2
# Line 28807 | Labeled: Cứu hoả kêu hú vậy mà ko thấy sịt à... → 1
# 💾 Checkpoint saved 5 comments (Total: 28806)
# Line 28808 | Labeled: sợ thế... → 3
# Line 28809 | Labeled: Mấy ông bà nói lắm😏... → 1
# Line 28810 | Labeled: trời ơi đã dịch bệnh mà còn cảnh này nữa 🥺... → 2
# Line 28811 | Labeled: mà vẫn ch thấy ngắt điện... → 2
# Line 28812 | Labeled: mô phật người không sao là tốt rồi... → 4
# 💾 Checkpoint saved 5 comments (Total: 28811)
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 label_and_export_comments(csv_output_file, labeled_csv_output_file, checkpoint_interval=5)
#
# Cell In[4], line 34, in label_and_export_comments(input_csv_file, output_csv_file, checkpoint_interval)
#      31     continue
#      33 # Gán nhãn cảm xúc
# ---> 34 emotion_label = label_emotion_with_lmstudio(text)
#      35 labeled_comment = {
#      36     'line_number': line_number,
#      37     'text': text,
#      38     'emotion_label': emotion_label
#      39 }
#      41 batch.append(labeled_comment)
#
# Cell In[3], line 57, in label_emotion_with_lmstudio(text)
#      49 payload = {
#      50     "messages": [{"role": "user", "content": prompt}],
#      51     "temperature": 0.3,
#      52     "max_tokens": 1,
#      53     "stop": ["\n"]
#      54 }
#      56 # Gọi API LM Studio
# ---> 57 response = requests.post(
#      58     "http://localhost:1234/v1/chat/completions",
#      59     headers={'Content-Type': 'application/json'},
#      60     json=payload,
#      61     timeout=600
#      62 )
#      64 # Xử lý response
#      65 response.raise_for_status()
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\urllib3\connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#     507 except BrokenPipeError:
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\urllib3\connection.py:445, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     443 for header, value in headers.items():
#     444     self.putheader(header, value)
# --> 445 self.endheaders()
#     447 # If we're given a body we start sending that in chunks.
#     448 if chunks is not None:
#
# File C:\laragon\bin\python\python-3.10\lib\http\client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1275 else:
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File C:\laragon\bin\python\python-3.10\lib\http\client.py:1037, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1035 msg = b"\r\n".join(self._buffer)
#    1036 del self._buffer[:]
# -> 1037 self.send(msg)
#    1039 if message_body is not None:
#    1040
#    1041     # create a consistent interface to message_body
#    1042     if hasattr(message_body, 'read'):
#    1043         # Let file-like take precedence over byte-like.  This
#    1044         # is needed to allow the current position of mmap'ed
#    1045         # files to be taken into account.
#
# File C:\laragon\bin\python\python-3.10\lib\http\client.py:975, in HTTPConnection.send(self, data)
#     973 if self.sock is None:
#     974     if self.auto_open:
# --> 975         self.connect()
#     976     else:
#     977         raise NotConnected()
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\urllib3\connection.py:276, in HTTPConnection.connect(self)
#     275 def connect(self) -> None:
# --> 276     self.sock = self._new_conn()
#     277     if self._tunnel_host:
#     278         # If we're tunneling it means we're connected to our proxy.
#     279         self._has_connected_to_proxy = True
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     193 """Establish a socket connection and set nodelay settings on it.
#     194
#     195 :return: New socket connection.
#     196 """
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#     205     raise NameResolutionError(self.host, self, e) from e
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:
