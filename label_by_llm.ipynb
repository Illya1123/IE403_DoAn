# %%
import requests
import json
import csv
import time
from urllib.parse import urlparse
import os

# %%
csv_output_file = './data/crawl/tiktok_comments.csv'
labeled_csv_output_file = './data/crawl/tiktok_comments_labeled.csv'

# %%
def label_emotion_with_lmstudio(text):
    """
    Phân loại cảm xúc văn bản tiếng Việt dùng LM Studio (local LLM) chỉ dựa trên text và teen code
    0: Vui vẻ, 1: Tức giận, 2: Buồn, 3: Sợ hãi, 4: Trung lập
    """
    try:
        # Validate input
        if not text or not isinstance(text, str):
            print("⚠️ Input không hợp lệ")
            return 4

        # Từ điển teen code phổ biến và cảm xúc tương ứng
        teen_code_dict = {
            # Vui vẻ
            "vk": 0, "vler": 0, "qtqd": 0, "ckđ": 0, "hehe": 0, "hihi": 0, "vcl": 0, "vl": 0,
            # Tức giận
            "dm": 1, "dmm": 1, "clm": 1, "clmm": 1, "dkm": 1, "dkmm": 1, "dcm": 1, "dcmm": 1, "lạy": 1,
            # Buồn
            "tđn": 2, "sml": 2, "cc": 2, "oz": 2, "tđb": 2, "tđx": 2,
            # sợ hãi
            "hãi": 3, "hú hồn": 3, "vl": 3, "bay màu": 3, "vãi đạn": 3
        }

        # Kiểm tra teen code (chuyển sang chữ thường để so sánh)
        lower_text = text.lower().strip()
        if lower_text in teen_code_dict:
            return teen_code_dict[lower_text]

        # Optimized prompt chỉ tập trung vào text và teen code
        prompt = """Bạn là chuyên gia phân loại cảm xúc và Hãy phân loại cảm xúc của 1 đoạn comment TIẾNG VIỆT sau thành 1 trong 5 số (chỉ dựa trên văn bản):
0: Vui vẻ - niềm vui, hạnh phúc, tích cực
   • Teen code: vk, vler, qtqd, ckđ, hehe, hihi
   VD: "Thật tuyệt vời", "Hôm nay là một ngày vui", "vk quá đi"
1: Tức giận - giận dữ, khó chịu, bực bội
   • Teen code: dm, dmm, clm, dkm
   VD: "Đồ ngu ngốc!", "Tao cực kỳ tức giận", "clm mày"
2: Buồn - nỗi buồn, thất vọng, đau khổ
   • Teen code: tđn, sml, oz, tđb
   VD: "Cuộc sống thật chán", "Hôm nay buồn quá", "sml rồi"
3: sợ hãi - lo âu (cảm xúc mà con người cảm nhận được khi cảm thấy mối đe doạ, nguy hiểm hoặc rủi ro, dù thật hay tưởng tượng)
   • Teen code: hãi vl, hú hồn chim én, sợ vl, thấy mà sợ
   VD: "Nghe kể chuyện ma xong mà sợ vl luôn á", "Nhìn cái mặt ông thầy lúc gọi tên tui mà hãi vl", ...
4: Trung lập - không cảm xúc rõ ràng
   VD: "Hôm nay trời mưa", "Tôi đi làm lúc 8 giờ", "Đây là thông tin khách quan"

Bình luận cần phân loại: "{}"
→ Chỉ trả về 1 số từ 0-4, không giải thích:""".format(text)

        payload = {
            "messages": [{"role": "user", "content": prompt}],
            "temperature": 0.3,
            "max_tokens": 1,
            "stop": ["\n"]
        }

        # Gọi API LM Studio
        response = requests.post(
            "http://localhost:1234/v1/chat/completions",
            headers={'Content-Type': 'application/json'},
            json=payload,
            timeout=600
        )

        # Xử lý response
        response.raise_for_status()
        result = response.json()
        
        # Lấy kết quả (đảm bảo chỉ lấy số)
        output = result["choices"][0]["message"]["content"].strip()
        
        if output.isdigit() and 0 <= int(output) <= 4:
            return int(output)
            
        print(f"⚠️ Kết quả không hợp lệ: '{output}' cho: '{text[:30]}...'")
        return 4
    
    except requests.exceptions.RequestException as e:
        print(f"❌ Lỗi kết nối LM Studio: '{text[:30]}...' | Lỗi: {str(e)}")
        return 4
    except Exception as e:
        print(f"❌ Lỗi xử lý: '{text[:30]}...' | Lỗi: {type(e).__name__}: {str(e)}")
        return 4

# %%
def label_and_export_comments(input_csv_file, output_csv_file, checkpoint_interval=10):
    import csv, os, time

    labeled_comments = []
    processed_lines = set()

    # Nếu file output đã tồn tại, đọc các dòng đã xử lý
    if os.path.exists(output_csv_file):
        with open(output_csv_file, 'r', encoding='utf-8') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                if 'line_number' in row:
                    processed_lines.add(int(row['line_number']))

    print(f"🔄 Tiếp tục gán nhãn. Đã gán: {len(processed_lines)} comments")

    try:
        with open(input_csv_file, 'r', encoding='utf-8') as csvfile:
            all_lines = list(csvfile.readlines())

        header = all_lines[0].strip().split(',')  # get column names
        reader = csv.DictReader(all_lines[1:], fieldnames=header)
        batch = []

        for line_number, row in enumerate(reader, start=2):  # start=2 vì dòng 1 là header
            if line_number in processed_lines:
                continue

            text = row.get('text', '').strip()
            if not text:
                continue

            # Gán nhãn cảm xúc
            emotion_label = label_emotion_with_lmstudio(text)
            labeled_comment = {
                'line_number': line_number,
                'text': text,
                'emotion_label': emotion_label
            }

            batch.append(labeled_comment)
            processed_lines.add(line_number)

            print(f"Line {line_number} | Labeled: {text[:50]}... → {emotion_label}")

            # Lưu checkpoint
            if len(batch) >= checkpoint_interval:
                save_to_csv(output_csv_file, batch)
                print(f"💾 Checkpoint saved {len(batch)} comments (Total: {len(processed_lines)})")
                batch.clear()

            time.sleep(3)  # tránh bị rate limit

        # Lưu phần còn lại
        if batch:
            save_to_csv(output_csv_file, batch)
            print(f"✅ Final save {len(batch)} comments (Total: {len(processed_lines)})")

    except Exception as e:
        print(f"\n❌ Error during labeling: {str(e)}")


def save_to_csv(file_path, data, fieldnames=['line_number', 'text', 'emotion_label']):
    file_exists = os.path.exists(file_path)
    with open(file_path, 'a', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        if not file_exists:
            writer.writeheader()
        writer.writerows(data)

# %% [markdown]
# ### Phân loại cảm xúc
# 0: Vui vẻ, 1: Tức giận, 2: Buồn bã, 3: Sợ hãi, 4: Trung lập.

# %%
label_and_export_comments(csv_output_file, labeled_csv_output_file, checkpoint_interval=5)
# Out:
# 🔄 Tiếp tục gán nhãn. Đã gán: 30 comments
# Line 32 | Labeled: Anh Tùng bảo trọng, chúc anh may mắn... → 0
# Line 33 | Labeled: quá nhẹ tay với tội phạm....... → 1
# Line 34 | Labeled: đây là lý do tôi k bao g dừng đèn đỏ:)... → 0
# Line 35 | Labeled: Từ nay ra đường không nên dừng đèn đỏ nha mng... → 4
# Line 36 | Labeled: sợ quá huỷ vé bay đến cần thơ ngày lễ 30/4 rồi đi ... → 3
# 💾 Checkpoint saved 5 comments (Total: 35)
# Line 37 | Labeled: tộc cối ở Cần thơ nhiều lắm... → 4
# Line 38 | Labeled: học trò gwen... → 4
# Line 39 | Labeled: hết dám đi chơi:)... → 2
# Line 40 | Labeled: Có khi cố tình để lấy số!... → 4
# Line 41 | Labeled: r khi quay đầu k có xe tải nào hết hả... → 4
# 💾 Checkpoint saved 5 comments (Total: 40)
# Line 42 | Labeled: kiểu nài ai dám xuống cân thơ chơi nữa trời 😳... → 3
# Line 43 | Labeled: namkiki tôi đó🥰🥰... → 0
# Line 44 | Labeled: Tự nhiên ra đường cái k đụng chạm j ai củng sợ nga... → 3
# Line 45 | Labeled: Ủa ở Vũng tàu má ơi... → 4
# Line 46 | Labeled: Giờ gặp đèn đỏ chắc vượt luôn chứ giờ nguy hiểm qu... → 3
# 💾 Checkpoint saved 5 comments (Total: 45)
# Line 47 | Labeled: Lúc đầu thì "Tùng Bò đâm, xong 1 lúc sau thì "vào ... → 0
# Line 48 | Labeled: bắt đc chưa... → 4
# Line 49 | Labeled: Bên Mỹ à... → 4
# Line 50 | Labeled: nghe cần thơ nổi hết da gà... → 0
# Line 51 | Labeled: người ta nhắc nhở thôi... có làm gì đâu... → 4
# 💾 Checkpoint saved 5 comments (Total: 50)
# Line 52 | Labeled: Trường Con Nam Định sợ nhất những người như này “ ... → 3
# Line 53 | Labeled: trường con sợ nhất những người âm thầm... → 3
# Line 54 | Labeled: Khen CA.địa phương. Quá giỏi... → 0
# Line 55 | Labeled: Giờ camera đầy đường có chạy đằng trời... → 4
# Line 56 | Labeled: tui bên Đồng Tháp vợ tui rủ qua Cần Thơ chơi rồi t... → 0
# 💾 Checkpoint saved 5 comments (Total: 55)
# Line 57 | Labeled: Công an Việt Nam đỉnh thiệt 😂... → 0
# Line 58 | Labeled: Thằng em áo đen ko hiểu chuyện gì luôn tội nghiệp ... → 2
# Line 59 | Labeled: Sợ thế 😭😭😭 ra đường giờ ko biết đâu mà tránh... → 3
# Line 60 | Labeled: luật rất nhân đạo nên ko trông mong lắm vào quyết ... → 4
# Line 61 | Labeled: ra người gặp kiểu này sợ không giám ra đường luôn ... → 3
# 💾 Checkpoint saved 5 comments (Total: 60)
# Line 62 | Labeled: bắt quá nhanh 🥰 Công An Việt Nam mình quá giỏi, xu... → 0
# Line 63 | Labeled: ngay nhà mình... → 4
# Line 64 | Labeled: Riết chắc tới đèn đỏ rồi núp luôn quá. chứ lâu lâu... → 1
# Line 65 | Labeled: may mà bắt sớm chứ sợ thật... → 3
# Line 66 | Labeled: 21h 8/4 hả?? lúc này t cũng đang ở ngoài đường luô... → 4
# 💾 Checkpoint saved 5 comments (Total: 65)
# Line 67 | Labeled: Gì trời. Xã hội kì vậy... → 4
# Line 68 | Labeled: trời ơi trời sợ quá trời khổ thiệt tội nghiệp Em d... → 3
# Line 69 | Labeled: Bộ công an nên đề xuất làm sao để không xảy ra nhữ... → 4
# Line 70 | Labeled: Sợ thế... → 3
# Line 71 | Labeled: Giờ ko lẽ ko đi ra đg luôn . Nghe mà sợ 😢😢... → 3
# 💾 Checkpoint saved 5 comments (Total: 70)
# Line 72 | Labeled: giờ ra đường chắc phải mặc áo giáp vào chỗ ăn toàn... → 1
# Line 73 | Labeled: Tự dưng họa đâu tới zị ..... → 2
# Line 74 | Labeled: Về đồn là hiểu liền ......ko đùa dk vs các ah đâu... → 4
# Line 75 | Labeled: Anh em gì của Gwen hay gì mà cắt tùm lum vậy ba 😂... → 1
# Line 76 | Labeled: ôi trời 🙏🙏... → 0
# 💾 Checkpoint saved 5 comments (Total: 75)
# Line 77 | Labeled: Công an Việt Nam quá đỉnh... → 0
