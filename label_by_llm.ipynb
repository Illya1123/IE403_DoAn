# %%
import requests
import json
import csv
import time
from urllib.parse import urlparse
import os

# %%
csv_output_file = './data/crawl/tiktok_comments.csv'
labeled_csv_output_file = './data/crawl/tiktok_comments_labeled.csv'

# %%
def label_emotion_with_lmstudio(text):
    """
    Phân loại cảm xúc văn bản tiếng Việt dùng LM Studio (local LLM) chỉ dựa trên text và teen code
    0: Vui vẻ, 1: Tức giận, 2: Buồn, 3: Sợ hãi, 4: Trung lập
    """
    try:
        # Validate input
        if not text or not isinstance(text, str):
            print("⚠️ Input không hợp lệ")
            return 4

        # Từ điển teen code phổ biến và cảm xúc tương ứng
        teen_code_dict = {
            # Vui vẻ
            "vk": 0, "vler": 0, "qtqd": 0, "ckđ": 0, "hehe": 0, "hihi": 0, "vcl": 0, "vl": 0,
            # Tức giận
            "dm": 1, "dmm": 1, "clm": 1, "clmm": 1, "dkm": 1, "dkmm": 1, "dcm": 1, "dcmm": 1, "lạy": 1,
            # Buồn
            "tđn": 2, "sml": 2, "cc": 2, "oz": 2, "tđb": 2, "tđx": 2,
            # sợ hãi
            "hãi": 3, "hú hồn": 3, "vl": 3, "bay màu": 3, "vãi đạn": 3
        }

        # Kiểm tra teen code (chuyển sang chữ thường để so sánh)
        lower_text = text.lower().strip()
        if lower_text in teen_code_dict:
            return teen_code_dict[lower_text]

        # Optimized prompt chỉ tập trung vào text và teen code
        prompt = """Bạn là chuyên gia phân loại cảm xúc và Hãy phân loại cảm xúc của 1 đoạn comment TIẾNG VIỆT sau thành 1 trong 5 số (chỉ dựa trên văn bản):
0: Vui vẻ - niềm vui, hạnh phúc, tích cực
   • Teen code: vk, vler, qtqd, ckđ, hehe, hihi
   VD: "Thật tuyệt vời", "Hôm nay là một ngày vui", "vk quá đi"
1: Tức giận - giận dữ, khó chịu, bực bội
   • Teen code: dm, dmm, clm, dkm
   VD: "Đồ ngu ngốc!", "Tao cực kỳ tức giận", "clm mày"
2: Buồn - nỗi buồn, thất vọng, đau khổ
   • Teen code: tđn, sml, oz, tđb
   VD: "Cuộc sống thật chán", "Hôm nay buồn quá", "sml rồi"
3: sợ hãi - lo âu (cảm xúc mà con người cảm nhận được khi cảm thấy mối đe doạ, nguy hiểm hoặc rủi ro, dù thật hay tưởng tượng)
   • Teen code: hãi vl, hú hồn chim én, sợ vl, thấy mà sợ
   VD: "Nghe kể chuyện ma xong mà sợ vl luôn á", "Nhìn cái mặt ông thầy lúc gọi tên tui mà hãi vl", ...
4: Trung lập - không cảm xúc rõ ràng
   VD: "Hôm nay trời mưa", "Tôi đi làm lúc 8 giờ", "Đây là thông tin khách quan"

Bình luận cần phân loại: "{}"
→ Chỉ trả về 1 số từ 0-4, không giải thích:""".format(text)

        payload = {
            "messages": [{"role": "user", "content": prompt}],
            "temperature": 0.3,
            "max_tokens": 1,
            "stop": ["\n"]
        }

        # Gọi API LM Studio
        response = requests.post(
            "http://localhost:1234/v1/chat/completions",
            headers={'Content-Type': 'application/json'},
            json=payload,
            timeout=600
        )

        # Xử lý response
        response.raise_for_status()
        result = response.json()
        
        # Lấy kết quả (đảm bảo chỉ lấy số)
        output = result["choices"][0]["message"]["content"].strip()
        
        if output.isdigit() and 0 <= int(output) <= 4:
            return int(output)
            
        print(f"⚠️ Kết quả không hợp lệ: '{output}' cho: '{text[:30]}...'")
        return 4
    
    except requests.exceptions.RequestException as e:
        print(f"❌ Lỗi kết nối LM Studio: '{text[:30]}...' | Lỗi: {str(e)}")
        return 4
    except Exception as e:
        print(f"❌ Lỗi xử lý: '{text[:30]}...' | Lỗi: {type(e).__name__}: {str(e)}")
        return 4

# %%
def label_and_export_comments(input_csv_file, output_csv_file, checkpoint_interval=10):
    import csv, os, time

    labeled_comments = []
    processed_lines = set()

    # Nếu file output đã tồn tại, đọc các dòng đã xử lý
    if os.path.exists(output_csv_file):
        with open(output_csv_file, 'r', encoding='utf-8') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                if 'line_number' in row:
                    processed_lines.add(int(row['line_number']))

    print(f"🔄 Tiếp tục gán nhãn. Đã gán: {len(processed_lines)} comments")

    try:
        with open(input_csv_file, 'r', encoding='utf-8') as csvfile:
            all_lines = list(csvfile.readlines())

        header = all_lines[0].strip().split(',')  # get column names
        reader = csv.DictReader(all_lines[1:], fieldnames=header)
        batch = []

        for line_number, row in enumerate(reader, start=2):  # start=2 vì dòng 1 là header
            if line_number in processed_lines:
                continue

            text = row.get('text', '').strip()
            if not text:
                continue

            # Gán nhãn cảm xúc
            emotion_label = label_emotion_with_lmstudio(text)
            labeled_comment = {
                'line_number': line_number,
                'text': text,
                'emotion_label': emotion_label
            }

            batch.append(labeled_comment)
            processed_lines.add(line_number)

            print(f"Line {line_number} | Labeled: {text[:50]}... → {emotion_label}")

            # Lưu checkpoint
            if len(batch) >= checkpoint_interval:
                save_to_csv(output_csv_file, batch)
                print(f"💾 Checkpoint saved {len(batch)} comments (Total: {len(processed_lines)})")
                batch.clear()

            time.sleep(3)  # tránh bị rate limit

        # Lưu phần còn lại
        if batch:
            save_to_csv(output_csv_file, batch)
            print(f"✅ Final save {len(batch)} comments (Total: {len(processed_lines)})")

    except Exception as e:
        print(f"\n❌ Error during labeling: {str(e)}")


def save_to_csv(file_path, data, fieldnames=['line_number', 'text', 'emotion_label']):
    file_exists = os.path.exists(file_path)
    with open(file_path, 'a', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        if not file_exists:
            writer.writeheader()
        writer.writerows(data)

# %% [markdown]
# ### Phân loại cảm xúc
# 0: Vui vẻ, 1: Tức giận, 2: Buồn bã, 3: Sợ hãi, 4: Trung lập.

# %%
label_and_export_comments(csv_output_file, labeled_csv_output_file, checkpoint_interval=5)
# Out:
# 🔄 Tiếp tục gán nhãn. Đã gán: 15125 comments
# Line 15127 | Labeled: @người tình mùa nước lũ @🌧️🐥 tấm cám 5.0... → 4
# Line 15128 | Labeled: @qanhqanh:... → 4
# Line 15129 | Labeled: @Gia Minh... → 4
# Line 15130 | Labeled: mô phật mong ông bình an... → 4
# Line 15131 | Labeled: @Th05... → 4
# 💾 Checkpoint saved 5 comments (Total: 15130)
# Line 15132 | Labeled: @Sebastian058 tốt zới tui quá 😂... → 0
# Line 15133 | Labeled: @Huy Hùng... → 4
# Line 15134 | Labeled: @Cu Đùm 🤍... → 4
# Line 15135 | Labeled: @ɴԍọc ʙước 😆... → 0
# Line 15136 | Labeled: @Quỳnh Như... → 4
# 💾 Checkpoint saved 5 comments (Total: 15135)
# Line 15137 | Labeled: @kcj... → 4
# Line 15138 | Labeled: @𝚅𝚊̆𝚗 𝙻𝚞̛𝚘̛̣𝚗𝚐🐬... → 4
# Line 15139 | Labeled: @i'm yours @Liaa 😳... → 0
# Line 15140 | Labeled: @giahuy103_... → 4
# Line 15141 | Labeled: @ThảoMi🫧... → 4
# 💾 Checkpoint saved 5 comments (Total: 15140)
# Line 15142 | Labeled: @Tiểu chuỗi🔥... → 0
# Line 15143 | Labeled: @Quang Trường7427... → 4
# Line 15144 | Labeled: @Trần Rin... → 4
# Line 15145 | Labeled: cảm giác mạnh=))) nhm hơi nguy hiểm... → 0
# Line 15146 | Labeled: Bật tăng tẳng luôn khác gì trò chơi mạo hiểm 😂... → 0
# 💾 Checkpoint saved 5 comments (Total: 15145)
# Line 15147 | Labeled: @ㅤㅤㅤㅤㅤㅤㅤㅤㅤㅤMeo Meo 🍓... → 4
# Line 15148 | Labeled: @hehe @xisswort @weniii @⋆ᡣ𐭩.𖥔˚･ ｡☆∴｡ @🧚‍♀️ @yyyyy... → 0
# Line 15149 | Labeled: @Minh Hy hí hì hi @🧸 @ND Ngọc Ánh🤍... → 0
# Line 15150 | Labeled: @Rếch✌ tấm cám... → 4
# Line 15151 | Labeled: @Như Quỳnh 🤗 @nhung (￣ヘ￣)... → 0
# 💾 Checkpoint saved 5 comments (Total: 15150)
# Line 15152 | Labeled: @Gấu tên Tài... → 4
# Line 15153 | Labeled: @Ngọc Kim🫧 tấm cám... → 4
# Line 15154 | Labeled: @Nhảm nhí 🍒... → 1
# Line 15155 | Labeled: @VVTP vãi thật... → 1
# Line 15156 | Labeled: @Ngọc Phương... → 4
# 💾 Checkpoint saved 5 comments (Total: 15155)
# Line 15157 | Labeled: @chocopai🤡 tấm cám ngoài đời... → 4
# Line 15158 | Labeled: @𝙗𝙖𝙤𝙩𝙝𝙮🎀... → 4
# Line 15159 | Labeled: toi yếu tim... → 3
# Line 15160 | Labeled: Cha nội ơi con sợ cái cưa giùmmmm... → 3
# Line 15161 | Labeled: @nhungocc @nam @ptkute... → 4
# 💾 Checkpoint saved 5 comments (Total: 15160)
# Line 15162 | Labeled: Ai cười ai cười đó ai ai... → 0
# Line 15163 | Labeled: @Dương Ng Kim Tuyền 👩🏻‍⚕️ @Kim Hậu @Sinh Tố Dâu🍓 🤣... → 0
# Line 15164 | Labeled: @Tờ Mờ 🤌... → 4
# Line 15165 | Labeled: Tấm cám chỉ là cái tên 💔 [photo]... → 2
# Line 15166 | Labeled: @yan @mi hề... → 0
# 💾 Checkpoint saved 5 comments (Total: 15165)
# 💾 Checkpoint saved 5 comments (Total: 15245)
# Line 15247 | Labeled: nguyên đàn cám 🥰... → 0
# Line 15248 | Labeled: Vua khỉ mất roi 😢 hên cho a nha... → 2
# Line 15249 | Labeled: @Huỳnh Minh Tiến... → 4
# Line 15250 | Labeled: @Thanh Diệu🌸... → 4
# Line 15251 | Labeled: @👺... → 4
# 💾 Checkpoint saved 5 comments (Total: 15250)
# Line 15252 | Labeled: @ỏ🍒... → 4
# Line 15253 | Labeled: 😁😁😁... → 0
# Line 15254 | Labeled: @ối chòi oi... → 0
# Line 15255 | Labeled: @mina.isszz @Thuý Vy ông nội ơi... → 4
# Line 15256 | Labeled: nguy hiểm nhaa... → 3
# 💾 Checkpoint saved 5 comments (Total: 15255)
# Line 15257 | Labeled: @bellu... → 4
# Line 15258 | Labeled: @Khó tính nên khổ tình .... → 4
# Line 15259 | Labeled: @BéNy... → 4
# Line 15260 | Labeled: tưởng AI... → 4
# Line 15261 | Labeled: :) ê nha... → 0
# 💾 Checkpoint saved 5 comments (Total: 15260)
# Line 15262 | Labeled: trời nguy hiểm vãi... → 3
# Line 15263 | Labeled: @Huytran... → 4
# Line 15264 | Labeled: @ngocjj__... → 4
# Line 15265 | Labeled: này tấm cám ngoại truyện... → 4
# Line 15266 | Labeled: @ph.... → 4
# 💾 Checkpoint saved 5 comments (Total: 15265)
# Line 15267 | Labeled: @Thiên Kim... → 4
# Line 15268 | Labeled: @DDApr2091... → 4
# Line 15269 | Labeled: @Holly Molly tấm cám nè chời... → 0
# Line 15270 | Labeled: @Dinh Tin Dat sợ 🥺... → 3
# Line 15271 | Labeled: @Bông 😭... → 2
# 💾 Checkpoint saved 5 comments (Total: 15270)
# Line 15272 | Labeled: @TRỌNG HỮU 🐃 @quochuy200504 @9th3... → 4
# Line 15273 | Labeled: @Ngọc Tỷ dhs Hàn Quốc... → 4
# Line 15274 | Labeled: @Midu @Bỏ Phố Về Quê😈... → 4
# Line 15275 | Labeled: 😂😂😂... → 0
# Line 15276 | Labeled: @f ☺️... → 0
# 💾 Checkpoint saved 5 comments (Total: 15275)
# Line 15277 | Labeled: Rồi ỗng hoá peter vàng anh chui vào tay áo... → 4
# Line 15278 | Labeled: Nhìn cái cưa sợ ghê... → 3
# Line 15279 | Labeled: @😭... → 2
# Line 15280 | Labeled: @Hoàng Thành... → 4
# Line 15281 | Labeled: @kn. 🍭... → 4
# 💾 Checkpoint saved 5 comments (Total: 15280)
# Line 15282 | Labeled: @Ngọc Hiền... → 4
# Line 15283 | Labeled: @D E N D I ✅... → 4
# Line 15284 | Labeled: @MAP... → 4
# Line 15285 | Labeled: @t.huyxtr... → 4
# Line 15286 | Labeled: @Tú Tú🌽 =))))... → 0
# 💾 Checkpoint saved 5 comments (Total: 15285)
# Line 15287 | Labeled: @bdat... → 4
# Line 15288 | Labeled: @loanbabi tấm cám chuyện chưa kể... → 4
# Line 15289 | Labeled: @Embe hay ngủ😪 @thphan776... → 4
# Line 15290 | Labeled: @Lâm Thức... → 4
# Line 15291 | Labeled: hên là k bị gì á... → 3
# 💾 Checkpoint saved 5 comments (Total: 15290)
# Line 15292 | Labeled: tấm cám... → 4
# Line 15293 | Labeled: @Vy Lê... → 4
# Line 15294 | Labeled: 🗣dựt đọt dừa đừng có dựt t=))... → 0
# Line 15295 | Labeled: @Trường Nguyễn Văn... → 4
# Line 15296 | Labeled: red bull đăng lại kìa😭... → 2
# 💾 Checkpoint saved 5 comments (Total: 15295)
# Line 15297 | Labeled: k thấy hài chỗ nào mà ghép nhạc vậy, lo cho chú ta... → 2
# Line 15298 | Labeled: @Công Huy... → 4
# Line 15299 | Labeled: @Đồng Tấn Phát... → 4
# Line 15300 | Labeled: @Bồ thằng Phê😂😂... → 0
# Line 15301 | Labeled: tr ơiiii tim cái cmt dữ v tr
# video t đăng lên xh❌
# ... → 2
# 💾 Checkpoint saved 5 comments (Total: 15300)
# Line 15302 | Labeled: @qnga🫧... → 4
# Line 15303 | Labeled: @Khánh Thi @Nhật Red... → 4
# Line 15304 | Labeled: 🤣🤣🤣... → 0
# Line 15305 | Labeled: Ác hơn mẹ Cám nữa🤣... → 1
# Line 15306 | Labeled: @thanhxink0 j v tr... → 1
# 💾 Checkpoint saved 5 comments (Total: 15305)
# Line 15307 | Labeled: @Võ Minh Thư... → 4
# Line 15308 | Labeled: ra p2 nha... → 4
# Line 15309 | Labeled: @Nii @nhuu quynhh 😆... → 0
# Line 15310 | Labeled: cưa cây mà lấy dây kéo mà ng ko biết kéo có ngày m... → 4
# Line 15311 | Labeled: lí do phụ nữ sống thọ hơn đàn ông.... → 4
# 💾 Checkpoint saved 5 comments (Total: 15310)
# Line 15312 | Labeled: @70,9 kí có nên cười k tr... → 4
# Line 15313 | Labeled: ổng kiểu : lâu lâu làm người nhện á... → 0
# Line 15314 | Labeled: cô tấm bị cám chơi... → 2
# Line 15315 | Labeled: @Phương... → 4
# Line 15316 | Labeled: @xing gái tinh quái... → 1
# 💾 Checkpoint saved 5 comments (Total: 15315)
# Line 15317 | Labeled: @Tân... → 4
# Line 15318 | Labeled: @bún nước lèo... → 4
# Line 15319 | Labeled: @thanbacc... → 4
# Line 15320 | Labeled: @Hoàng Giang... → 4
# Line 15321 | Labeled: @Trung Hiếu @thachkiet6... → 4
# 💾 Checkpoint saved 5 comments (Total: 15320)
# Line 15322 | Labeled: @khanh ngoc. @𓃱 @boni @xù... → 4
# Line 15323 | Labeled: 🤣🤣🤣... → 0
# Line 15324 | Labeled: @Minh... → 4
# Line 15325 | Labeled: @vaniskibidi... → 4
# Line 15326 | Labeled: @hân ngọc... → 4
# 💾 Checkpoint saved 5 comments (Total: 15325)
# Line 15327 | Labeled: nguy hiểm... → 3
# Line 15328 | Labeled: 👌👌👌... → 4
# Line 15329 | Labeled: Quá nguy hiễm... → 3
# Line 15330 | Labeled: tấm cám... → 4
# Line 15331 | Labeled: @Bảo... → 4
# 💾 Checkpoint saved 5 comments (Total: 15330)
# Line 15332 | Labeled: @Ngọt 🎀 😢😢... → 2
# Line 15374 | Labeled: Hồn bay phách lạc... → 0
# Line 15375 | Labeled: @Linhcute2712><... → 4
# Line 15376 | Labeled: Ng thiệt ak chời... → 4
# 💾 Checkpoint saved 5 comments (Total: 15375)
# Line 15377 | Labeled: @bé chin... → 4
# Line 15378 | Labeled: @Ngọc Anh... → 4
# Line 15379 | Labeled: Al... → 4
# Line 15380 | Labeled: @Mĩm... → 4
# Line 15381 | Labeled: @Heo Xinhh... → 4
# 💾 Checkpoint saved 5 comments (Total: 15380)
# Line 15382 | Labeled: @꧁༒•ᵛᵐᶜʰⁱⁿʰ•༒꧂... → 4
# Line 15383 | Labeled: @Thảo 🐙... → 4
# Line 15384 | Labeled: @ǫᴜốᴄ ᴋɪᴇ̣̂ᴛ ʙɪᴇ̂ɴ ʜᴏᴀ̀ 🎀... → 4
# Line 15385 | Labeled: @Huỳnh Thanh 💫... → 4
# Line 15386 | Labeled: @BIAN.H... → 4
# 💾 Checkpoint saved 5 comments (Total: 15385)
# Line 15387 | Labeled: 😌😌😌... → 0
# Line 15388 | Labeled: @Camly1109... → 4
# Line 15389 | Labeled: @Cẩm Tú 🤗... → 4
# Line 15390 | Labeled: @👑Kem❤️... → 0
# Line 15391 | Labeled: @userl2henwm8tv... → 4
# 💾 Checkpoint saved 5 comments (Total: 15390)
# Line 15392 | Labeled: @Nguyễn Thu Hằng... → 4
# Line 15393 | Labeled: cận cảnh cám chặt cây gít tấm... → 4
# Line 15394 | Labeled: Lma 😂😂 cười đái 😂😂... → 0
# Line 15395 | Labeled: @Cục đông sương 😂... → 0
# Line 15396 | Labeled: @𝙇𝙤𝙞 𝙉𝙜𝙪𝙮𝙚𝙣 @người tình mùa đông... → 4
# 💾 Checkpoint saved 5 comments (Total: 15395)
# Line 15397 | Labeled: @Đu Đủ... → 4
# Line 15398 | Labeled: @Duy... → 4
# Line 15399 | Labeled: @Chill... → 4
# Line 15400 | Labeled: 😂😂😂... → 0
# Line 15401 | Labeled: 🥰🥰🥰... → 0
# 💾 Checkpoint saved 5 comments (Total: 15400)
# Line 15402 | Labeled: @Hồng phúc ✅... → 4
# Line 15403 | Labeled: 😂... → 0
# Line 15404 | Labeled: xoay 380 độ.... → 4
# Line 15405 | Labeled: @45kg đổi tên 🤦... → 4
# Line 15406 | Labeled: @tine... → 4
# 💾 Checkpoint saved 5 comments (Total: 15405)
# Line 15407 | Labeled: @yếnnhi❤_(cá🐳)... → 0
# Line 15408 | Labeled: @Minh Minh... → 4
# Line 15409 | Labeled: @Nguyễn Thành Cường... → 4
# Line 15410 | Labeled: đăng cái video k ai tim đi cmt dạo 100 mấy tim...💔... → 2
# Line 15411 | Labeled: @2k19😈... → 4
# 💾 Checkpoint saved 5 comments (Total: 15410)
# Line 15412 | Labeled: @Cát Cát 😂... → 0
# Line 15413 | Labeled: @CụcMỡ 😂... → 0
# Line 15414 | Labeled: @Henry Cao @người đẹp vì app🫣 😅... → 0
# Line 15415 | Labeled: @kimmkatt... → 4
# Line 15536 | Labeled: “Bạn khiến tôi muốn học hát ngay lập tức.”... → 0
# 💾 Checkpoint saved 5 comments (Total: 15535)
# Line 15537 | Labeled: Cảm ơn video này, nó giúp mình vượt qua một ngày t... → 0
# Line 15538 | Labeled: “Giọng hát của bạn như một làn gió mới, thật sự rấ... → 0
# Line 15539 | Labeled: “Video này khiến tôi muốn nhảy múa theo bạn.”... → 0
# Line 15540 | Labeled: “Giọng hát của bạn khiến tôi muốn học hát ngay lập... → 0
# Line 15541 | Labeled: “Nếu có thể, tôi sẽ nghe bạn hát cả ngày.”... → 0
# 💾 Checkpoint saved 5 comments (Total: 15540)
# Line 15542 | Labeled: Có những điều bình dị nhưng lại vô cùng quý giá…... → 0
# Line 15543 | Labeled: Chỉ cần một cái ôm cũng đủ làm ngày ta sáng lên.... → 0
# Line 15544 | Labeled: “Giọng hát của bạn khiến tôi quên hết mệt mỏi.”... → 0
# Line 15545 | Labeled: “Bạn là nguồn cảm hứng lớn cho tôi.”... → 0
# Line 15546 | Labeled: Ai xem mà rơm rớm nước mắt giống tui hông?... → 2
# 💾 Checkpoint saved 5 comments (Total: 15545)
# Line 15547 | Labeled: Gia đình – nơi bắt đầu và cũng là nơi kết thúc mọi... → 0
# Line 15548 | Labeled: “Giọng hát của bạn như một liều thuốc chữa lành tâ... → 0
# Line 15549 | Labeled: Ca sĩ hát live mà vẫn đỉnh quá trời!... → 0
# Line 15550 | Labeled: Ai đó giúp tui lưu lại video này với!... → 4
# Line 15551 | Labeled: Chỉ cần một cái ôm cũng đủ làm ngày ta sáng lên.... → 0
# 💾 Checkpoint saved 5 comments (Total: 15550)
# Line 15552 | Labeled: “Bạn hát như thể đang kể câu chuyện của chính mình... → 0
# Line 15553 | Labeled: Thế giới này cần nhiều người làm nội dung như bạn.... → 0
# Line 15554 | Labeled: “Bạn xứng đáng được công nhận rộng rãi hơn nữa.”... → 0
# Line 15555 | Labeled: Gia đình – nơi bắt đầu và cũng là nơi kết thúc mọi... → 0
# Line 15556 | Labeled: Ai tới từ TikTok không? 😆... → 0
# 💾 Checkpoint saved 5 comments (Total: 15555)
# Line 15557 | Labeled: “Tôi đã rơi nước mắt khi nghe bạn hát, quá cảm độn... → 0
# Line 15558 | Labeled: “Giọng hát của bạn khiến tôi quên hết mệt mỏi.”... → 0
# Line 15559 | Labeled: “Video này khiến tôi muốn nhảy múa theo bạn.”... → 0
# Line 15560 | Labeled: Gửi đến ba mẹ, những người hùng thầm lặng.... → 0
# Line 15561 | Labeled: “Video này như một liều thuốc tinh thần, cảm ơn bạ... → 0
# 💾 Checkpoint saved 5 comments (Total: 15560)
# Line 15562 | Labeled: Cảm ơn video này, nó giúp mình vượt qua một ngày t... → 0
# Line 15563 | Labeled: Ai đó giúp tui lưu lại video này với!... → 4
# Line 15564 | Labeled: Có những điều bình dị nhưng lại vô cùng quý giá…... → 0
# Line 15565 | Labeled: Gửi đến ba mẹ, những người hùng thầm lặng.... → 0
# Line 15566 | Labeled: Lời bài hát sâu lắng quá, nghe mà muốn khóc luôn.... → 2
# 💾 Checkpoint saved 5 comments (Total: 15565)
# Line 15567 | Labeled: Đôi khi chỉ cần một video để thay đổi cả suy nghĩ.... → 4
# Line 15568 | Labeled: Pure talent here!... → 0
# Line 15569 | Labeled: “Tôi đã phải dừng video này lại vì không thể ngừng... → 0
# Line 15570 | Labeled: I didn’t expect that ending! 😲... → 4
# Line 15571 | Labeled: “Nếu âm nhạc là phép màu, thì bạn chính là phù thủ... → 0
# 💾 Checkpoint saved 5 comments (Total: 15570)
# Line 15572 | Labeled: Cho 1 like vì video quá chất lượng!... → 0
# Line 15573 | Labeled: Ai xem mà rơm rớm nước mắt giống tui hông?... → 2
# Line 15574 | Labeled: Ai tới từ TikTok không? 😆... → 0
# Line 15575 | Labeled: Cho 1 like vì video quá chất lượng!... → 0
# Line 15576 | Labeled: Gửi đến ba mẹ, những người hùng thầm lặng.... → 0
# 💾 Checkpoint saved 5 comments (Total: 15575)
# Line 15577 | Labeled: Người ta gọi đây là content có “tâm hồn”.... → 4
# Line 15578 | Labeled: Ai làm sub chắc đang khóc trong góc phòng =))... → 0
# Line 15579 | Labeled: Không chỉ hay, mà còn rất thông minh!... → 0
# Line 15580 | Labeled: Lời bài hát sâu lắng quá, nghe mà muốn khóc luôn.... → 2
# Line 15581 | Labeled: Bạn không chỉ làm video – bạn đang kể chuyện.... → 0
# 💾 Checkpoint saved 5 comments (Total: 15580)
# Line 15582 | Labeled: Gửi đến ba mẹ, những người hùng thầm lặng.... → 0
# Line 15583 | Labeled: Một video, nhiều cung bậc cảm xúc!... → 0
# Line 15584 | Labeled: Cuộc sống giống như video này: nhanh, gọn và đầy b... → 0
# Line 15585 | Labeled: Big respect from [your country] 🇻🇳... → 0
# Line 15586 | Labeled: Pure talent here!... → 0
# 💾 Checkpoint saved 5 comments (Total: 15585)
# Line 15587 | Labeled: “Video này khiến tôi muốn nhảy múa theo bạn.”... → 0
# Line 15588 | Labeled: “Giọng hát của bạn khiến tôi muốn làm một album ri... → 0
# Line 15589 | Labeled: “Video này như một liều thuốc tinh thần, cảm ơn bạ... → 0
# Line 15590 | Labeled: Cảm ơn vì đã làm mình nhớ đến những người yêu thươ... → 0
# Line 15591 | Labeled: Cảm giác xem xong được truyền thêm động lực sống á... → 0
# 💾 Checkpoint saved 5 comments (Total: 15590)
# Line 15592 | Labeled: Cuộc sống giống như video này: nhanh, gọn và đầy b... → 0
# Line 15593 | Labeled: Beat chất, lời ý nghĩa, MV thì xịn xò!... → 0
# Line 15594 | Labeled: Không chỉ hay, mà còn rất thông minh!... → 0
# Line 15595 | Labeled: “Bài hát này khiến tôi nhớ về những kỷ niệm xưa.”... → 2
# Line 15596 | Labeled: Big respect from [your country] 🇻🇳... → 0
# 💾 Checkpoint saved 5 comments (Total: 15595)
# Line 15597 | Labeled: This made my day ❤️... → 0
# Line 15598 | Labeled: “Tôi đã phải dừng video này lại vì không thể ngừng... → 0
# Line 15599 | Labeled: “Nếu có thể, tôi sẽ nghe bạn hát cả ngày.”... → 0
# Line 15600 | Labeled: “Giọng hát của bạn khiến tôi quên hết mệt mỏi.”... → 0
# Line 15601 | Labeled: MV đầu tư như phim điện ảnh luôn á!... → 0
# 💾 Checkpoint saved 5 comments (Total: 15600)
# Line 15602 | Labeled: “Giọng hát của bạn khiến tôi muốn làm một album ri... → 0
# Line 15603 | Labeled: “Bạn đã truyền tải cảm xúc qua từng nốt nhạc, thật... → 0
# Line 15604 | Labeled: Bạn không chỉ làm video – bạn đang kể chuyện.... → 0
# Line 15605 | Labeled: Bộ video này hack dopamine đúng không???... → 0
# Line 15606 | Labeled: “Giọng hát của bạn khiến tôi quên hết mọi lo toan.... → 0
# 💾 Checkpoint saved 5 comments (Total: 15605)
# Line 15607 | Labeled: “Giọng hát của bạn khiến tôi muốn học hát ngay lập... → 0
# Line 15608 | Labeled: “Bạn hát như thể đang kể một câu chuyện, quá cảm x... → 0
# Line 15609 | Labeled: “Tôi đã nghe đi nghe lại video này cả ngày, không ... → 0
# Line 15610 | Labeled: “Nếu có thể, tôi sẽ nghe bạn hát cả ngày.”... → 0
# Line 15611 | Labeled: Cảm giác xem xong được truyền thêm động lực sống á... → 0
# 💾 Checkpoint saved 5 comments (Total: 15610)
# Line 15612 | Labeled: “Giọng hát của bạn khiến tôi muốn học hát ngay lập... → 0
# Line 15613 | Labeled: “Tôi đã rơi nước mắt khi nghe bạn hát, quá cảm độn... → 0
# Line 15614 | Labeled: “Tôi đã phải dừng video này lại vì không thể ngừng... → 0
# Line 15615 | Labeled: Giọng hát của bạn như một làn gió mới, thật sự rất... → 0
# Line 15616 | Labeled: “Bạn khiến tôi muốn học hát ngay lập tức.”... → 0
# 💾 Checkpoint saved 5 comments (Total: 15615)
# Line 15617 | Labeled: “Video này khiến tôi muốn nhảy múa theo bạn.”... → 0
# Line 15618 | Labeled: “Giọng hát của bạn khiến tôi quên hết mệt mỏi.”... → 0
# Line 15619 | Labeled: Gia đình – nơi bắt đầu và cũng là nơi kết thúc mọi... → 0
# Line 15620 | Labeled: Giai điệu này không thoát ra được luôn!... → 2
# Line 15621 | Labeled: “Bạn đã truyền tải cảm xúc qua từng nốt nhạc, thật... → 0
# 💾 Checkpoint saved 5 comments (Total: 15620)
# Line 15622 | Labeled: Video này chứng minh: không cần nhiều tiền vẫn làm... → 0
# Line 15623 | Labeled: Nếu bạn thấy comment này, chúc bạn một ngày tốt là... → 0
# Line 15624 | Labeled: Cho 1 like vì video quá chất lượng!... → 0
# Line 15625 | Labeled: Beat chất, lời ý nghĩa, MV thì xịn xò!... → 0
# Line 15626 | Labeled: Này là video hay nhất trong tuần của tui luôn nè!... → 0
# 💾 Checkpoint saved 5 comments (Total: 15625)
# Line 15627 | Labeled: Ai đó giúp tui lưu lại video này với!... → 4
# Line 15628 | Labeled: Có những điều bình dị nhưng lại vô cùng quý giá…... → 0
# Line 15629 | Labeled: “Nếu có thể, tôi sẽ nghe bạn hát cả ngày.”... → 0
# Line 15630 | Labeled: “Giọng hát của bạn như một làn gió mới, thật sự rấ... → 0
# Line 15631 | Labeled: Đây chính là lý do vì sao mình yêu Internet.... → 0
# 💾 Checkpoint saved 5 comments (Total: 15630)
# Line 15632 | Labeled: Hát là một chuyện, truyền cảm xúc mới là đỉnh cao!... → 0
# Line 15633 | Labeled: Rojoooooo😳... → 0
# Line 15634 | Labeled: Ai đó trả lời tui đi, video này quay ở đâu vậy?... → 4
# Line 15635 | Labeled: Có những điều bình dị nhưng lại vô cùng quý giá…... → 0
# Line 15636 | Labeled: WOW just wow…... → 0
# 💾 Checkpoint saved 5 comments (Total: 15635)
# Line 15637 | Labeled: Beat chất, lời ý nghĩa, MV thì xịn xò!... → 0
# Line 15638 | Labeled: “Nếu có thể, tôi sẽ nghe bạn hát cả ngày.”... → 0
# Line 15639 | Labeled: “Video này như một liều thuốc tinh thần, cảm ơn bạ... → 0
# Line 15640 | Labeled: Đôi khi chỉ cần một video để thay đổi cả suy nghĩ.... → 4
# Line 15641 | Labeled: “Giọng hát của bạn khiến bài hát này trở nên đặc b... → 0
# 💾 Checkpoint saved 5 comments (Total: 15640)
# Line 15642 | Labeled: Có những điều bình dị nhưng lại vô cùng quý giá…... → 0
# Line 15643 | Labeled: Mỗi giây trong video này đều đáng quý.... → 0
# Line 15644 | Labeled: Giá trị không nằm ở view, mà ở cảm xúc để lại.... → 0
# Line 15645 | Labeled: “Giọng hát của bạn khiến tôi quên hết mệt mỏi.”... → 0
# Line 15646 | Labeled: Nhờ video này mình đã học được nhiều điều hay ho.... → 0
# 💾 Checkpoint saved 5 comments (Total: 15645)
# Line 15647 | Labeled: Đúng người, đúng thời điểm, đúng video.... → 0
# Line 15648 | Labeled: “Giọng hát của bạn như một bản tình ca, thật sự rấ... → 0
# Line 15649 | Labeled: Đôi khi chỉ cần một video để thay đổi cả suy nghĩ.... → 4
# Line 15650 | Labeled: Càng xem càng thấy quý giá.... → 0
# Line 15651 | Labeled: Legendary content 🔥... → 0
# 💾 Checkpoint saved 5 comments (Total: 15650)
# Line 15652 | Labeled: “Giọng hát của bạn khiến tôi muốn nhảy múa ngay lậ... → 0
# Line 15653 | Labeled: “Bạn khiến tôi muốn học hát ngay lập tức.”... → 0
# Line 15654 | Labeled: Cho xin tọa độ chỗ quay video với ạ!... → 4
# Line 15655 | Labeled: Tui không cô đơn khi xem đi xem lại video này chứ?... → 2
# Line 15656 | Labeled: Một video, nhiều cung bậc cảm xúc!... → 0
# 💾 Checkpoint saved 5 comments (Total: 15655)
# Line 15657 | Labeled: Không phải video, mà là một liều thuốc tinh thần!... → 0
# Line 15658 | Labeled: “Bạn khiến tôi muốn học hát ngay lập tức.”... → 0
# Line 15659 | Labeled: Ai đó trả lời tui đi, video này quay ở đâu vậy?... → 4
# Line 15660 | Labeled: Ai cũng nên xem video này ít nhất 1 lần!... → 0
# Line 15661 | Labeled: This needs more views!... → 4
# 💾 Checkpoint saved 5 comments (Total: 15660)
# Line 15662 | Labeled: My new obsession!... → 0
# Line 15663 | Labeled: Một video, nhiều cung bậc cảm xúc!... → 0
# Line 15664 | Labeled: Đúng người, đúng thời điểm, đúng video.... → 0
# Line 15665 | Labeled: “Tôi đã phải dừng video này lại vì không thể ngừng... → 0
# Line 15666 | Labeled: “Bạn đã truyền tải cảm xúc qua từng nốt nhạc, thật... → 0
# 💾 Checkpoint saved 5 comments (Total: 15665)
# Line 15667 | Labeled: @dewieka... → 4
# Line 15668 | Labeled: Ca sĩ hát live mà vẫn đỉnh quá trời!... → 0
# Line 15669 | Labeled: “Bạn khiến tôi muốn học hát ngay lập tức.”... → 0
# Line 15670 | Labeled: melasi njir... → 1
# Line 15671 | Labeled: WOW just wow…... → 0
# 💾 Checkpoint saved 5 comments (Total: 15670)
# Line 15672 | Labeled: Đây là nội dung khiến tui tin vào Internet trở lại... → 0
# Line 15673 | Labeled: “Giọng hát của bạn khiến tôi quên hết mọi lo toan.... → 0
# Line 15674 | Labeled: Giá trị không nằm ở view, mà ở cảm xúc để lại.... → 0
# Line 15675 | Labeled: Rất cần nhiều nội dung tích cực như thế này mỗi ng... → 0
# Line 15676 | Labeled: Chúng ta đều cần những phút giây như thế này.... → 0
# 💾 Checkpoint saved 5 comments (Total: 15675)
# Line 15677 | Labeled: “Giọng hát của bạn như một làn gió mới, thật sự rấ... → 0
# Line 15678 | Labeled: 😭😭😭... → 2
# Line 15679 | Labeled: Ih seruuuuu... → 0
# Line 15680 | Labeled: 🥺... → 0
# Line 15681 | Labeled: 🙏... → 4
# 💾 Checkpoint saved 5 comments (Total: 15680)
# Line 15682 | Labeled: 😂😂😂... → 0
# Line 15683 | Labeled: 🤣🤣🤣... → 0
# Line 15684 | Labeled: 🥰... → 0
# Line 15685 | Labeled: @cii♊... → 4
# Line 15686 | Labeled: @kitty 🐱 @nunaa Pie to pakde iki😫😭... → 2
# 💾 Checkpoint saved 5 comments (Total: 15685)
# Line 15687 | Labeled: @Sinchia... → 4
# Line 15688 | Labeled: 😳... → 4
# Line 15689 | Labeled: 🤣🤣🤣🤣... → 0
# Line 15690 | Labeled: @nouser @r.a @vrzta... → 4
# Line 15691 | Labeled: baputar kiri ke kiri maniseeew... → 4
# 💾 Checkpoint saved 5 comments (Total: 15690)
# Line 15692 | Labeled: @saa🌺... → 4
# Line 15693 | Labeled: 'ha? ' sedetik😭... → 2
# Line 15694 | Labeled: Perjuangan🥺... → 2
# Line 15695 | Labeled: @EL... → 4
# Line 15696 | Labeled: @Zuwi_datina... → 4
# 💾 Checkpoint saved 5 comments (Total: 15695)
# Line 15697 | Labeled: chỗ t có ng chết vì nghề này... → 2
# Line 15698 | Labeled: @isah @nbila... → 4
# Line 15699 | Labeled: @ʀɪssᴀᴄʜᴜᴜ･֊･ goyang goyang 🤭... → 0
# Line 15700 | Labeled: bole liat stories aku ga??... → 4
# Line 15701 | Labeled: @annn @nanayyy... → 4
# 💾 Checkpoint saved 5 comments (Total: 15700)
# Line 15702 | Labeled: @strangers @VLEZH... → 4
# Line 15703 | Labeled: lak kenek senso ne pie jal kui😭🗿... → 2
# Line 15829 | Labeled: 🤣🤣🤣... → 0
# Line 15830 | Labeled: Thường là thấy ngta buộc dây vào máy cưa,mấy pha v... → 4
# Line 15831 | Labeled: Ai tư vấn công trình này vậy cả nhà, làm tui thót ... → 3
# 💾 Checkpoint saved 5 comments (Total: 15830)
# Line 15832 | Labeled: 🤣🤣🤣... → 0
# Line 15833 | Labeled: Ê nghe @@kiet và những người bẹn... → 4
# Line 15834 | Labeled: gf... → 4
# Line 15835 | Labeled: Trúng chân chảy máu kìa... → 3
# Line 15836 | Labeled: @Băc... → 4
# 💾 Checkpoint saved 5 comments (Total: 15835)
# Line 15837 | Labeled: Hãi tới già tấm cám đời thực... → 3
# Line 15838 | Labeled: sợ cái cưa trúng ng... → 3
# Line 15839 | Labeled: hình như trúng chân... → 3
# Line 15840 | Labeled: 🍀🍀🍀... → 4
# Line 15841 | Labeled: Trời ạ, nguy hiểm quá xem mà thoát cả tim... → 3
# 💾 Checkpoint saved 5 comments (Total: 15840)
# Line 15842 | Labeled: Tr ơi coi lại nick đăng hết hồn... → 3
# Line 15843 | Labeled: 😏... → 4
# Line 15844 | Labeled: tấm cám bản đời thực :)))... → 0
# Line 15845 | Labeled: @Lạc Lạc... → 4
# Line 15846 | Labeled: t ghê cái cưa quá... → 1
# 💾 Checkpoint saved 5 comments (Total: 15845)
# Line 15847 | Labeled: 🙏🙏🙏... → 4
# Line 15848 | Labeled: @laladden... → 4
# Line 15849 | Labeled: My dad fell off one of these and that’s why he has... → 3
# Line 15850 | Labeled: @Chinmi 🧸 @Thùy An ❤... → 0
# Line 15851 | Labeled: tấm cám đời thựcc 😇... → 2
# 💾 Checkpoint saved 5 comments (Total: 15850)
# Line 15852 | Labeled: 😁😁😁... → 0
# Line 15853 | Labeled: 😳... → 4
# Line 15854 | Labeled: ê nguy hiểm vậy... → 3
# Line 15855 | Labeled: Nguy hiểm vậy 😢... → 3
# Line 15856 | Labeled: ké🍀... → 0
# 💾 Checkpoint saved 5 comments (Total: 15855)
# Line 15857 | Labeled: 😂... → 0
# Line 15858 | Labeled: @tao bị khờ... → 4
# Line 15859 | Labeled: Tui coi mà tê dò nè... → 3
# Line 15860 | Labeled: 1 tấm - 4 cám - 3 mụ vì ghẻee... → 1
# Line 15861 | Labeled: @Kngoc @Ngân Đào✨... → 4
# 💾 Checkpoint saved 5 comments (Total: 15860)
# Line 15862 | Labeled: ko chị chảy máu gì tui cũng chịu... → 4
# Line 15863 | Labeled: hú hôn chưa rớt 😂😂😂😂... → 0
# Line 15864 | Labeled: cũng vì cơm áo gạo tiền mà nguy hiểm quá... → 3
# Line 15865 | Labeled: @Ngọc nè💋... → 4
# Line 15866 | Labeled: 😁😁😁... → 0
# 💾 Checkpoint saved 5 comments (Total: 15865)
# Line 15867 | Labeled: chú cưa kiểu
# Báo chư phật dìa ăn cơm với con 😂... → 0
# Line 15868 | Labeled: thịt cây còn dày mà cố kéo cho đứt chả vậy... → 1
# Line 15869 | Labeled: chỉ có Việt Nam tui mới giam chơi cỡ này... → 1
# Line 15870 | Labeled: tí về suối... → 4
# Line 15871 | Labeled: quá nguy hiểm... → 3
# 💾 Checkpoint saved 5 comments (Total: 15870)
# Line 15872 | Labeled: Tấm cám bước ra từ câu chuyện hả... → 4
# Line 15873 | Labeled: T nghe cái nhạc xong nhìn lên cười không nhặt dc m... → 0
# Line 15874 | Labeled: chắc bỏ nghề luôn... → 2
# Line 15875 | Labeled: Um... → 4
# Line 15876 | Labeled: cho tiền bao nhiêu tôi cũng ko chèo lên đâu... → 1
# 💾 Checkpoint saved 5 comments (Total: 15875)
# Line 15877 | Labeled: 😂... → 0
# Line 15878 | Labeled: Úi dời ơi, may là a ấy coa tí nghề trong người🥰... → 0
# Line 15879 | Labeled: làm gì khôn quá dị😳... → 1
# Line 15880 | Labeled: 😄😄😄😄... → 0
# Line 15881 | Labeled: ơ động đất à.ko phải đó là cây dừa đang rung... → 4
# 💾 Checkpoint saved 5 comments (Total: 15880)
# Line 15882 | Labeled: @người đẹp cần ngủ😴... → 4
# Line 15883 | Labeled: Xíu nữa lên thiên đàng😂... → 0
# Line 15884 | Labeled: @Mèo không ăn cá🌻 😂😂... → 0
# Line 15885 | Labeled: kh bt đáng trách hay đáng cười nữa🤗... → 4
# Line 15886 | Labeled: 😂😂😂... → 0
# 💾 Checkpoint saved 5 comments (Total: 15885)
# Line 15887 | Labeled: theo tui biết là tiền công ko nhiều sao mấy ổng ch... → 2
# Line 15888 | Labeled: @.⋆♱ 𝐆𝐢𝐚𝐚𝐁𝐚𝐨𝐨.✮🧸... → 4
# Line 15889 | Labeled: @123llol... → 4
# Line 15890 | Labeled: @chongiu cụa Nduyên🫵🫰 @Ngọc Duyên @𝘿𝙪𝙮 𝙇𝙞𝙣𝙝💥... → 4
# Line 15891 | Labeled: Quá nguy hiểm... → 3
# 💾 Checkpoint saved 5 comments (Total: 15890)
# Line 15892 | Labeled: @Thu Hà 34🇻🇳16🇯🇵... → 4
# Line 15893 | Labeled: 💗💗💗... → 0
# Line 15894 | Labeled: nhìn cảnh này giống tấm cám nhỉ... → 4
# Line 15895 | Labeled: Xl vì tui đã cười... → 0
# Line 15896 | Labeled: tưởng all... → 4
# 💾 Checkpoint saved 5 comments (Total: 15895)
# Line 15897 | Labeled: ở trên đó chắc nội thương 😂... → 0
# Line 15898 | Labeled: hoá giải lời nguyền comment... → 4
# Line 15899 | Labeled: mạo hiểm ghê quá... → 3
# Line 15900 | Labeled: sao không. mở. miệng trước cắt bên còn lại dức kho... → 1
# Line 15901 | Labeled: như xiếc zị... → 4
# 💾 Checkpoint saved 5 comments (Total: 15900)
# Line 15902 | Labeled: kkkk... → 0
# Line 15903 | Labeled: Cừ xỉu😂😂... → 0
# Line 15904 | Labeled: con lạy dì .. dì tha cho connnn , dì ơiii , dì ơii... → 2
# Line 15905 | Labeled: @Pé Bắp 🤣... → 0
# Line 15906 | Labeled: 😅😅😅.nhìn sợ thiệt... → 3
# 💾 Checkpoint saved 5 comments (Total: 15905)
# Line 15907 | Labeled: @🤡... → 4
# Line 15908 | Labeled: Ê bay t vô thức lấy tay ra đỡ 😳😳... → 4
# ...
# Line 16929 | Labeled: 😂😂😂... → 0
# Line 16930 | Labeled: kéo quá nên mới như vậy. c... → 2
# Line 16931 | Labeled: lúc sinh thời cha con rất thích ăn cau 🤣🤣... → 0
# 💾 Checkpoint saved 5 comments (Total: 16930)
# Line 16932 | Labeled: @trà ĐàoNgonLắmm (✿◕ ‿ ◕✿)... → 0
# Line 16933 | Labeled: @ng tình new tấm ơi nay giỗ cha con ra kia trèo ca... → 0
# Line 16934 | Labeled: suýt thì dcc lm cô Tấm😇😇😇... → 1
# Line 16935 | Labeled: @🐣... → 4
# Line 16936 | Labeled: @tuquy_0.4... → 4
# 💾 Checkpoint saved 5 comments (Total: 16935)
# Line 16937 | Labeled: may cái cưa chx trúng ng ổ... → 1
# Line 16938 | Labeled: ê má... → 4
# Line 16939 | Labeled: Ông bà độ... → 4
# Line 16940 | Labeled: @Tr. Lam🌷 @Ph.Quí💤 @Zynekk💤 @yêu mình anh. @𝙦𝙖💗 @N... → 4
# Line 16941 | Labeled: Nhìn lư.ỡi cưa nguy hiểm quá, mong chú sẽ luôn bìn... → 3
# 💾 Checkpoint saved 5 comments (Total: 16940)
# Line 16942 | Labeled: 🙂🙂🙂... → 0
# Line 16943 | Labeled: Chắc t xuống địa ngục quá... → 2
# Line 16944 | Labeled: 😇... → 0
# Line 16945 | Labeled: @😘... → 0
# Line 16946 | Labeled: @hanhuquynh04 @su @kimmngann__ @Ê ! @HaanHaan @Nhu... → 4
# 💾 Checkpoint saved 5 comments (Total: 16945)
# Line 16947 | Labeled: mấy ông làm nhìn ớn ăn quá.😨😨... → 3
# Line 16948 | Labeled: 😒... → 4
# Line 16949 | Labeled: 😆😆😆... → 0
# Line 16950 | Labeled: hoang dã dị ní... → 1
# Line 16951 | Labeled: @meow💞 @Hồng Hài Nhi 💗... → 0
# 💾 Checkpoint saved 5 comments (Total: 16950)
# Line 16952 | Labeled: @Thuỳ Dung❤️Cherry 🍒... → 0
# Line 16953 | Labeled: chưa đếm 123 đã kéo. rồi 😁😁... → 0
# Line 16954 | Labeled: Tấm cám bản live... → 4
# Line 16955 | Labeled: kk... → 4
# Line 16956 | Labeled: Cái máy nó quật vào chân vậy có sao không trời, ý ... → 3
# 💾 Checkpoint saved 5 comments (Total: 16955)
# Line 16957 | Labeled: Nhìn kìa, là Tấm đang nô đùa với đám dì ghẻ... → 4
# Line 16958 | Labeled: Gì v... → 4
# Line 16959 | Labeled: 😂😂... → 0
# Line 16960 | Labeled: 😂😂😂... → 0
# Line 16961 | Labeled: 🔀... → 4
# 💾 Checkpoint saved 5 comments (Total: 16960)
# Line 16962 | Labeled: @mt?... → 4
# Line 16963 | Labeled: Chỗ t có ng trèo cây rồi bị rớt, mất luôn ấy. Nhìn... → 3
# Line 16964 | Labeled: @🫧... → 4
# Line 16965 | Labeled: @Nhu Y @na @.... → 4
# Line 16966 | Labeled: haha, nhìn sợ quá😅😅😅... → 0
# 💾 Checkpoint saved 5 comments (Total: 16965)
# Line 16967 | Labeled: 🤣🤣🤣... → 0
# Line 16968 | Labeled: bấm đừng r chú bai xuống đi... → 1
# Line 16969 | Labeled: ổng kểu 2viên bị đánh loạn xạ ☠️... → 1
# Line 16970 | Labeled: @Weiwei @Liinh... → 4
# Line 16971 | Labeled: @Diễm Hương tấm cám phiên bản đời thực... → 4
# 💾 Checkpoint saved 5 comments (Total: 16970)
# Line 16972 | Labeled: song lần này đèo giảm lèo rùa... → 4
# Line 16973 | Labeled: @71chí nguyện💞 😎😎😎😎... → 0
# Line 16974 | Labeled: @Plinh🥹... → 0
# Line 16975 | Labeled: 😂😂😂... → 0
# Line 16976 | Labeled: @Thnhtm??... → 4
# 💾 Checkpoint saved 5 comments (Total: 16975)
# Line 16977 | Labeled: @Đếm Ngày Xa Em🫠... → 2
# Line 16978 | Labeled: Do bất cẩn trong quá trình cưa dừa........ → 4
# Line 16979 | Labeled: @want to be loved... → 4
# Line 16980 | Labeled: May cái cưa nó ko vào chân chú ý he... → 4
# Line 16981 | Labeled: @9498thutrang 🤣🤣🤣... → 0
# 💾 Checkpoint saved 5 comments (Total: 16980)
# Line 16982 | Labeled: @Tú Đào... → 4
# Line 16983 | Labeled: @Mai ơiiiii... → 0
# Line 16984 | Labeled: nhìn v thôi chứ xuống tới là cái quần ướt nhẹp... → 1
# Line 16985 | Labeled: ổn 😂... → 0
# Line 16986 | Labeled: @Vo doan🫰🏻 @Voanh🐣 @late love... → 0
# 💾 Checkpoint saved 5 comments (Total: 16985)
# Line 16987 | Labeled: t xuống địa ngục đây... → 2
# Line 16988 | Labeled: Cô Tấm đây rồi... → 4
# Line 16989 | Labeled: Xém tý đi toà cả xóm 😁... → 0
# Line 16990 | Labeled: sợ quá hà 🥺... → 3
# Line 16991 | Labeled: ❕... → 4
# 💾 Checkpoint saved 5 comments (Total: 16990)
# Line 16992 | Labeled: @trwg.nhathoang tấm câm live action... → 1
# Line 16993 | Labeled: M tính hại t hả cám : )))... → 1
# Line 16994 | Labeled: ult ...... → 4
# Line 16995 | Labeled: Cảnh này chỉ có ở VN😁... → 0
# Line 16996 | Labeled: rung khỏi cây 🌲... → 4
# 💾 Checkpoint saved 5 comments (Total: 16995)
# Line 16997 | Labeled: @hgKhánh @AMOR FATI 🎨... → 4
# Line 16998 | Labeled: ê má... → 4
# Line 16999 | Labeled: =))... → 0
# Line 17000 | Labeled: @htrang... → 4
# Line 17001 | Labeled: như trên cành câyy😁... → 0
# 💾 Checkpoint saved 5 comments (Total: 17000)
# Line 17002 | Labeled: Có ai nhăn mặt khi xem k... → 4
# Line 17003 | Labeled: hên quá cô tấm xém rớt r🥰... → 0
# Line 17004 | Labeled: @chgiul🤣🤣... → 0
# Line 17005 | Labeled: cái cơ tắt chưa lắc qua lắc lại nhìn ghê thế... → 1
# Line 17006 | Labeled: xem mà hồi hộp :))... → 3
# 💾 Checkpoint saved 5 comments (Total: 17005)
# Line 17007 | Labeled: Người trên cây và cái bản nhạc khiến t tưởng tượng... → 4
# Line 17008 | Labeled: thì ra đây là bản gốc của phân đoạn tấm leo cây... → 4
# Line 17009 | Labeled: @Híp’p... → 4
# Line 17010 | Labeled: làm trò chơi gi v... → 4
# Line 17011 | Labeled: 😳😳😳😳... → 4
# 💾 Checkpoint saved 5 comments (Total: 17010)
# Line 17012 | Labeled: Game 1 mạng... → 3
# Line 17013 | Labeled: @Linh Như 🌷... → 4
# Line 17014 | Labeled: chấn động thiên lý ơi... → 0
# Line 17015 | Labeled: tr quư nam mô... → 4
# Line 17016 | Labeled: 🌘... → 4
# 💾 Checkpoint saved 5 comments (Total: 17015)
# Line 17017 | Labeled: @Ánh Tuyết... → 4
# Line 17018 | Labeled: @sin... → 4
# Line 17019 | Labeled: Hú cả hồn😂... → 3
# Line 17020 | Labeled: trả... → 4
# Line 17021 | Labeled: @-T R Â N N È🧏🏻‍♀️-... → 4
# 💾 Checkpoint saved 5 comments (Total: 17020)
# Line 17022 | Labeled: tất cả vì cuộc sống mưu sinh nguy hiểm quá... → 3
# Line 17023 | Labeled: @10hngurui quãi đạn... → 1
# Line 17024 | Labeled: Có vỡ ko chú... → 4
# Line 17025 | Labeled: @Én nèeeee 🤣 cứu =)))))... → 0
# Line 17026 | Labeled: Hình như cưa đập vài chân roii😇... → 0
# 💾 Checkpoint saved 5 comments (Total: 17025)
# Line 17027 | Labeled: t tưởng ổng rớt xuống luôn á😇... → 3
# Line 17028 | Labeled: @Đậu Ngộ Hee... → 0
# Line 17029 | Labeled: 😇... → 0
# Line 17030 | Labeled: @HữuTính xsm nữa là hóng hớt rồi😌... → 0
# Line 17031 | Labeled: @✿KTrinh亗 @N. @Qbaoo❤️‍🩹 @Trần Ngọc @Alex tran... → 4
# 💾 Checkpoint saved 5 comments (Total: 17030)
# Line 17032 | Labeled: tr ơi mô phật... → 4
# Line 17033 | Labeled: 😅😅😅... → 0
# Line 17034 | Labeled: Tí thì đc chuyển kiếp... → 2
# Line 17035 | Labeled: Nhanh trí buông cái cưa ra... → 4
# Line 17036 | Labeled: @𝚖𝚒𝚗𝚑 tấm cám hã tr... → 4
# 💾 Checkpoint saved 5 comments (Total: 17035)
# Line 17037 | Labeled: dưới kéo mạnh quá nó dặt. kéo nhẹ nhẹ vừa đủ thôi... → 1
# Line 17038 | Labeled: @H ê chắc do tâm em ác 😭... → 2
# Line 17039 | Labeled: Nguy hiểm quá 🥲🥲🥲... → 3
# Line 17040 | Labeled: Rồi ổng có sao ko, cập nhập cho chúng toy đê... → 4
# Line 17041 | Labeled: 🤣🤣🤣... → 0
# 💾 Checkpoint saved 5 comments (Total: 17040)
# Line 17042 | Labeled: @Trà... → 4
# Line 17043 | Labeled: @🆖Hℹ️ tấm cám🤣... → 0
# Line 17044 | Labeled: @Nguyen Vu🎧 @𝐓𝐇𝐀𝐍𝐇 𝐓𝐔𝐍𝐆... → 4
# Line 17045 | Labeled: cháu dừng vid r chú xuống đi😭... → 2
# Line 17046 | Labeled: Tổ tiên gánh gãy lưng... → 1
# 💾 Checkpoint saved 5 comments (Total: 17045)
# Line 17047 | Labeled: khó nha bờ rô 😭🥰... → 2
# Line 17048 | Labeled: @Minh Phương... → 4
# Line 17049 | Labeled: tấm cám... → 4
# Line 17050 | Labeled: @Cá Mòi học TOCFL B1... → 4
# Line 17051 | Labeled: 4 con cám đang kéo, 2 dì ghẻ đang nhìn 😂... → 0
# 💾 Checkpoint saved 5 comments (Total: 17050)
# Line 17052 | Labeled: mặc dù ko thọ bằng con gái nhưng đc cái ko BH tuyệ... → 0
# Line 17053 | Labeled: repppp... → 4
# Line 17054 | Labeled: Nguy hiểm dị trèn lỡ chưa tắt máy cưa chắc bay cái... → 3
# Line 17055 | Labeled: có dây kéo rồi thì sao không cắt dứoi, xuống rồi m... → 4
# Line 17056 | Labeled: @tnmh252525... → 4
# 💾 Checkpoint saved 5 comments (Total: 17055)
# Line 17057 | Labeled: Ê Cái cưa ko sợ trúng người à... → 3
# Line 17058 | Labeled: @Đặng Hậu... → 4
# Line 17059 | Labeled: tấm cám ha tr... → 2
# Line 17060 | Labeled: @Nguyên Phụnq... → 4
# Line 17061 | Labeled: thua mẹ con cám cái giới tính... → 1
# 💾 Checkpoint saved 5 comments (Total: 17060)
# Line 17062 | Labeled: tr ơi. xã kế bên t có chú kia cũng cưa vầy nè. máy... → 3
# Line 17063 | Labeled: Tính ám sát chị tấm hẻ... → 1
# Line 17064 | Labeled: Quá nguy hiểm... → 3
# Line 17065 | Labeled: @Lectntd... → 4
# Line 17066 | Labeled: 😳... → 4
# 💾 Checkpoint saved 5 comments (Total: 17065)
# Line 17067 | Labeled: cám dg âm mưu hãm hại c tấm... → 1
# Line 17068 | Labeled: cưa dừa mà dựt dữ z mấy ông cố... → 1
# Line 17069 | Labeled: @thuốc ngủ 😌... → 4
# Line 17070 | Labeled: @Nguyễn Minh Anh haha... → 0
# Line 17071 | Labeled: 🙏🏻 nguy hiểm thật... → 3
# 💾 Checkpoint saved 5 comments (Total: 17070)
# Line 17072 | Labeled: 💀... → 4
# Line 17073 | Labeled: T thấy trúng cái chân ha j ă... → 2
# Line 17074 | Labeled: game 1 mạng... → 4
# Line 17075 | Labeled: Cháu bấm dừng video rồi, chú thả cái cưa xuống đi ... → 3
# Line 17076 | Labeled: @CaO ThAnH 34🇻🇳💎  v... → 4
# 💾 Checkpoint saved 5 comments (Total: 17075)
# Line 17077 | Labeled: Ui troi lo cai cưa trung ổng😥... → 2
# Line 17078 | Labeled: Xém nớt nài😂😂😂... → 0
# Line 17079 | Labeled: @Bizonx.... → 4
# Line 17080 | Labeled: @3 Thằng Bắp Cùi... → 1
# Line 17081 | Labeled: @Daisy... → 4
# 💾 Checkpoint saved 5 comments (Total: 17080)
# Line 17082 | Labeled: @Mây cha oi cha... → 1
# Line 17083 | Labeled: @Tuan Do tấm cám... → 4
# Line 17084 | Labeled: @Đling ơ sao trên đấy r... → 4
# Line 17085 | Labeled: @Thua luôn👤. 😂😂😂... → 0
# Line 17086 | Labeled: @燕儿... → 4
# 💾 Checkpoint saved 5 comments (Total: 17085)
# Line 17087 | Labeled: 😂😂😂😂😂😂... → 0
# Line 17088 | Labeled: @Thanh Tuấn... → 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 label_and_export_comments(csv_output_file, labeled_csv_output_file, checkpoint_interval=5)
#
# Cell In[4], line 34, in label_and_export_comments(input_csv_file, output_csv_file, checkpoint_interval)
#      31     continue
#      33 # Gán nhãn cảm xúc
# ---> 34 emotion_label = label_emotion_with_lmstudio(text)
#      35 labeled_comment = {
#      36     'line_number': line_number,
#      37     'text': text,
#      38     'emotion_label': emotion_label
#      39 }
#      41 batch.append(labeled_comment)
#
# Cell In[3], line 57, in label_emotion_with_lmstudio(text)
#      49 payload = {
#      50     "messages": [{"role": "user", "content": prompt}],
#      51     "temperature": 0.3,
#      52     "max_tokens": 1,
#      53     "stop": ["\n"]
#      54 }
#      56 # Gọi API LM Studio
# ---> 57 response = requests.post(
#      58     "http://localhost:1234/v1/chat/completions",
#      59     headers={'Content-Type': 'application/json'},
#      60     json=payload,
#      61     timeout=600
#      62 )
#      64 # Xử lý response
#      65 response.raise_for_status()
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File C:\laragon\bin\python\python-3.10\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File C:\laragon\bin\python\python-3.10\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File C:\laragon\bin\python\python-3.10\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File C:\laragon\bin\python\python-3.10\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:
