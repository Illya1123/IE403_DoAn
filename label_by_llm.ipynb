# %%
import requests
import json
import csv
import time
from urllib.parse import urlparse
import os

# %%
csv_output_file = './data/crawl/tiktok_comments.csv'
labeled_csv_output_file = './data/crawl/tiktok_comments_labeled.csv'

# %%
def label_emotion_with_lmstudio(text):
    """
    Phân loại cảm xúc văn bản tiếng Việt dùng LM Studio (local LLM) chỉ dựa trên text và teen code
    0: Vui vẻ, 1: Tức giận, 2: Buồn, 3: Sợ hãi, 4: Trung lập
    """
    try:
        # Validate input
        if not text or not isinstance(text, str):
            print("⚠️ Input không hợp lệ")
            return 4

        # Từ điển teen code phổ biến và cảm xúc tương ứng
        teen_code_dict = {
            # Vui vẻ
            "vk": 0, "vler": 0, "qtqd": 0, "ckđ": 0, "hehe": 0, "hihi": 0, "vcl": 0, "vl": 0,
            # Tức giận
            "dm": 1, "dmm": 1, "clm": 1, "clmm": 1, "dkm": 1, "dkmm": 1, "dcm": 1, "dcmm": 1, "lạy": 1,
            # Buồn
            "tđn": 2, "sml": 2, "cc": 2, "oz": 2, "tđb": 2, "tđx": 2,
            # sợ hãi
            "hãi": 3, "hú hồn": 3, "vl": 3, "bay màu": 3, "vãi đạn": 3
        }

        # Kiểm tra teen code (chuyển sang chữ thường để so sánh)
        lower_text = text.lower().strip()
        if lower_text in teen_code_dict:
            return teen_code_dict[lower_text]

        # Optimized prompt chỉ tập trung vào text và teen code
        prompt = """Bạn là chuyên gia phân loại cảm xúc và Hãy phân loại cảm xúc của 1 đoạn comment TIẾNG VIỆT sau thành 1 trong 5 số (chỉ dựa trên văn bản):
0: Vui vẻ - niềm vui, hạnh phúc, tích cực
   • Teen code: vk, vler, qtqd, ckđ, hehe, hihi
   VD: "Thật tuyệt vời", "Hôm nay là một ngày vui", "vk quá đi"
1: Tức giận - giận dữ, khó chịu, bực bội
   • Teen code: dm, dmm, clm, dkm
   VD: "Đồ ngu ngốc!", "Tao cực kỳ tức giận", "clm mày"
2: Buồn - nỗi buồn, thất vọng, đau khổ
   • Teen code: tđn, sml, oz, tđb
   VD: "Cuộc sống thật chán", "Hôm nay buồn quá", "sml rồi"
3: sợ hãi - lo âu (cảm xúc mà con người cảm nhận được khi cảm thấy mối đe doạ, nguy hiểm hoặc rủi ro, dù thật hay tưởng tượng)
   • Teen code: hãi vl, hú hồn chim én, sợ vl, thấy mà sợ
   VD: "Nghe kể chuyện ma xong mà sợ vl luôn á", "Nhìn cái mặt ông thầy lúc gọi tên tui mà hãi vl", ...
4: Trung lập - không cảm xúc rõ ràng
   VD: "Hôm nay trời mưa", "Tôi đi làm lúc 8 giờ", "Đây là thông tin khách quan"

Bình luận cần phân loại: "{}"
→ Chỉ trả về 1 số từ 0-4, không giải thích:""".format(text)

        payload = {
            "messages": [{"role": "user", "content": prompt}],
            "temperature": 0.3,
            "max_tokens": 1,
            "stop": ["\n"]
        }

        # Gọi API LM Studio
        response = requests.post(
            "http://localhost:1234/v1/chat/completions",
            headers={'Content-Type': 'application/json'},
            json=payload,
            timeout=600
        )

        # Xử lý response
        response.raise_for_status()
        result = response.json()
        
        # Lấy kết quả (đảm bảo chỉ lấy số)
        output = result["choices"][0]["message"]["content"].strip()
        
        if output.isdigit() and 0 <= int(output) <= 4:
            return int(output)
            
        print(f"⚠️ Kết quả không hợp lệ: '{output}' cho: '{text[:30]}...'")
        return 4
    
    except requests.exceptions.RequestException as e:
        print(f"❌ Lỗi kết nối LM Studio: '{text[:30]}...' | Lỗi: {str(e)}")
        return 4
    except Exception as e:
        print(f"❌ Lỗi xử lý: '{text[:30]}...' | Lỗi: {type(e).__name__}: {str(e)}")
        return 4

# %%
def label_and_export_comments(input_csv_file, output_csv_file, checkpoint_interval=10):
    import csv, os, time

    labeled_comments = []
    processed_lines = set()

    # Nếu file output đã tồn tại, đọc các dòng đã xử lý
    if os.path.exists(output_csv_file):
        with open(output_csv_file, 'r', encoding='utf-8') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                if 'line_number' in row:
                    processed_lines.add(int(row['line_number']))

    print(f"🔄 Tiếp tục gán nhãn. Đã gán: {len(processed_lines)} comments")

    try:
        with open(input_csv_file, 'r', encoding='utf-8') as csvfile:
            all_lines = list(csvfile.readlines())

        header = all_lines[0].strip().split(',')  # get column names
        reader = csv.DictReader(all_lines[1:], fieldnames=header)
        batch = []

        for line_number, row in enumerate(reader, start=2):  # start=2 vì dòng 1 là header
            if line_number in processed_lines:
                continue

            text = row.get('text', '').strip()
            if not text:
                continue

            # Gán nhãn cảm xúc
            emotion_label = label_emotion_with_lmstudio(text)
            labeled_comment = {
                'line_number': line_number,
                'text': text,
                'emotion_label': emotion_label
            }

            batch.append(labeled_comment)
            processed_lines.add(line_number)

            print(f"Line {line_number} | Labeled: {text[:50]}... → {emotion_label}")

            # Lưu checkpoint
            if len(batch) >= checkpoint_interval:
                save_to_csv(output_csv_file, batch)
                print(f"💾 Checkpoint saved {len(batch)} comments (Total: {len(processed_lines)})")
                batch.clear()

            time.sleep(3)  # tránh bị rate limit

        # Lưu phần còn lại
        if batch:
            save_to_csv(output_csv_file, batch)
            print(f"✅ Final save {len(batch)} comments (Total: {len(processed_lines)})")

    except Exception as e:
        print(f"\n❌ Error during labeling: {str(e)}")


def save_to_csv(file_path, data, fieldnames=['line_number', 'text', 'emotion_label']):
    file_exists = os.path.exists(file_path)
    with open(file_path, 'a', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        if not file_exists:
            writer.writeheader()
        writer.writerows(data)

# %% [markdown]
# ### Phân loại cảm xúc
# 0: Vui vẻ, 1: Tức giận, 2: Buồn bã, 3: Sợ hãi, 4: Trung lập.

# %%
label_and_export_comments(csv_output_file, labeled_csv_output_file, checkpoint_interval=5)
# Out:
# 🔄 Tiếp tục gán nhãn. Đã gán: 8120 comments
# Line 8122 | Labeled: Nhà tôi sẽ ngược lại nha. T để cho ck đi ở công kh... → 2
# Line 8123 | Labeled: 😁😁😁... → 0
# Line 8124 | Labeled: chị vợ ko cần làm gì 2 đứa tự động lồi ra... → 0
# Line 8234 | Labeled: Nể mỗi anh này. Bản lĩnh nha. Được 🤣... → 0
# Line 8235 | Labeled: Nghiệp quat ca 2... → 4
# Line 8236 | Labeled: đàn ông chúng tôi yêu vợ lắm.nên chị e đừng bắt ch... → 0
# 💾 Checkpoint saved 5 comments (Total: 8235)
# Line 8237 | Labeled: Nhanh gọn lẹ ủng hộ 2 tay😂... → 0
# Line 8238 | Labeled: 😅 chịu luôn 🙂... → 4
# Line 8239 | Labeled: 😳😳😳... → 4
# Line 8240 | Labeled: Mấy bạn nữ nào đang là bé ba zô coi mà sáng mắt ra... → 1
# Line 8241 | Labeled: a ck này dk ấy 😂... → 0
# 💾 Checkpoint saved 5 comments (Total: 8240)
# Line 8242 | Labeled: Ơi là trời... → 4
# Line 8243 | Labeled: Ngoại tình n cũng có trách nhiệm vs vk đó🙏😅... → 1
# Line 8244 | Labeled: T mong tất cả những đứa bb3 sẽ gặp cái kết k kém k... → 2
# Line 8245 | Labeled: Y là y còn gd là số 1 người đàn ông bản lĩnh... → 0
# Line 8246 | Labeled: ( vãi các ông ) các ông chỉ muốn thêm, chứ ko muốn... → 1
# 💾 Checkpoint saved 5 comments (Total: 8245)
# Line 8247 | Labeled: @Namfoodboy cũng là 1 vấn đề... → 4
# Line 8248 | Labeled: kính a🤣🤣🤣... → 0
# Line 8249 | Labeled: chứng tỏ quá yêu vk 🤣cảm kích quá... → 0
# Line 8250 | Labeled: @emiu_cuaanh06... → 4
# Line 8251 | Labeled: Em nể mỗi anh thôi đấy 😁😁😁... → 0
# 💾 Checkpoint saved 5 comments (Total: 8250)
# Line 8252 | Labeled: H ct toàn thây k bầu là phải đội ơn nyc gòi, sừng ... → 1
# Line 8253 | Labeled: Trong những thằng cặp Bồ Em nể mỗi Anh🥱... → 0
# Line 8254 | Labeled: Tất cả những thằng ngoạ tình e nể mỗi a😂 chắc vk a... → 0
# Line 8255 | Labeled: @Black Lavender... → 4
# Line 8256 | Labeled: @KT... → 4
# 💾 Checkpoint saved 5 comments (Total: 8255)
# Line 8257 | Labeled: @SonBanh2k13 có tinh thần yêu vợ nma kh đáng kể🥰... → 0
# Line 8258 | Labeled: bâyh cái gì củng có thể xảy ra hết dị chời... → 4
# Line 8259 | Labeled: A là 1 tấm gương để các a ngoại tình noi theo. 😁... → 0
# Line 8260 | Labeled: cái kết khá hài lòng... → 0
# Line 8261 | Labeled: ra đời e nể mỗi anh :))... → 0
# 💾 Checkpoint saved 5 comments (Total: 8260)
# Line 8262 | Labeled: @Vũ Phạm... → 4
# Line 8263 | Labeled: chuẩn nét bóc bánh trả tiền trả luôn xác... → 1
# Line 8264 | Labeled: Ối zồi ôi... → 0
# Line 8265 | Labeled: @Minh Vũ... → 4
# Line 8266 | Labeled: Trà xanh rét liền... → 1
# 💾 Checkpoint saved 5 comments (Total: 8265)
# Line 8267 | Labeled: Bản lĩnh quá ha 😂... → 0
# Line 8268 | Labeled: @Việt Linh 😂😂... → 0
# Line 8269 | Labeled: Cái giả của phản bội... → 1
# Line 8270 | Labeled: quá da man 😳... → 1
# Line 8271 | Labeled: Nghĩ tới c vợ nghe tin kiểu 🥺... → 0
# 💾 Checkpoint saved 5 comments (Total: 8270)
# Line 8272 | Labeled: @賢❤️... → 0
# Line 8273 | Labeled: Giờ mới thấy ngoại tình cũng đúng nà... → 2
# Line 8274 | Labeled: từ giờ khối con giáp 13 không dám đòi làm chính th... → 0
# Line 8275 | Labeled: Nể... → 0
# Line 8276 | Labeled: 🤭🤭🤭... → 0
# 💾 Checkpoint saved 5 comments (Total: 8275)
# Line 8277 | Labeled: Gòi gòi. Giờ mấy bb3 đố giám xíu chồng ng ta về bỏ... → 0
# Line 8278 | Labeled: Ra đời em nể nhất anh 😂... → 0
# Line 8279 | Labeled: @Mèo 🍀... → 4
# Line 8280 | Labeled: Ng vui nhất là c vk... → 0
# Line 8281 | Labeled: @Đỗ Trọng Hiếu96... → 4
# 💾 Checkpoint saved 5 comments (Total: 8280)
# Line 8282 | Labeled: 😂😂... → 0
# Line 8283 | Labeled: ạ luôn :)))... → 0
# Line 8284 | Labeled: @Nam Kaito khó lói... → 4
# Line 8285 | Labeled: @Anh chung 😭... → 2
# Line 8286 | Labeled: 🤣🤣🤣... → 0
# 💾 Checkpoint saved 5 comments (Total: 8285)
# Line 8287 | Labeled: 🤣🤣🤣 thật ra chúng tôi ko bao giờ bỏ vợ... → 0
# Line 8288 | Labeled: nhân quả của tiểu tam kkk... → 1
# Line 8289 | Labeled: quen thì quen. HK co vô ép người ta li dị ngen.🤣🤣🤣... → 0
# Line 8290 | Labeled: Kh phải tao nhé 😂... → 0
# Line 8291 | Labeled: đấy các bé 3 cứ đòi ngt ly hôn vợ cho lắm vào... → 1
# 💾 Checkpoint saved 5 comments (Total: 8290)
# Line 8292 | Labeled: A chồng uy tín nhất năm chơi đúng luật nhưng vâ... → 4
# Line 8293 | Labeled: mấy a cặp bồ nên học hỏi a này 😝... → 0
# Line 8294 | Labeled: Là sao nữa... → 4
# Line 8295 | Labeled: T mong mấy con bb3 thấy đc cảnh này và bỏ nghề 🤭... → 1
# Line 8296 | Labeled: Ngta vẫn yêu vợ mà cứ bắt li hôn... → 1
# 💾 Checkpoint saved 5 comments (Total: 8295)
# Line 8297 | Labeled: Trong tất cả những thèng ck ngoại tình e nể mỗi a ... → 1
# Line 8298 | Labeled: cái kết đẹp... → 0
# Line 8299 | Labeled: đã k thích còn cứ sui... → 1
# Line 8300 | Labeled: 😂2025 đỉnh vãi đạn. Cái gì cũng có thể xảy ra😂... → 0
# Line 8301 | Labeled: @Dô tri làm mẹ em bé Salmon 🙂... → 0
# 💾 Checkpoint saved 5 comments (Total: 8300)
# Line 8302 | Labeled: sau các chị "bé ba" nhột,không dám "lên gân,lên cố... → 0
# Line 8303 | Labeled: Đấy đàn ông là phải yêu vợ🤭🤭🤭... → 0
# Line 8304 | Labeled: vậy là thương vk dữ chưa ??... → 0
# Line 8563 | Labeled: 😂😂😂... → 0
# Line 8564 | Labeled: ủa nhớ vụ này ở Trà Vinh lâu rồi mà ta... → 4
# Line 8565 | Labeled: e nể nhất a rồi😁😁😁😂... → 0
# Line 8566 | Labeled: Quả này các cụ phù hộ cho c vk lắm đây này. Giải q... → 0
# 💾 Checkpoint saved 5 comments (Total: 8565)
# Line 8567 | Labeled: sợ quá sợ quá,,,,... → 3
# Line 8568 | Labeled: @Cỏ🌱... → 4
# Line 8569 | Labeled: cái kết của ng thứ 3... → 4
# Line 8570 | Labeled: Quả táo đến sớm quá... → 4
# Line 8571 | Labeled: Cứ dị cho t.. mấy e bé bi chuẩn bị tinh thần hửi đ... → 1
# 💾 Checkpoint saved 5 comments (Total: 8570)
# Line 8572 | Labeled: @thamtran0780... → 4
# Line 8573 | Labeled: Bb3 cứ yên làm bb3 đi. Ai kêu dành chỗ chính thất ... → 1
# Line 8574 | Labeled: Chuc mung 2 bạn... → 0
# Line 8575 | Labeled: cạn tình, mất nghĩa🤣... → 2
# Line 8576 | Labeled: @Anh ba Xoài 😂... → 0
# 💾 Checkpoint saved 5 comments (Total: 8575)
# Line 8577 | Labeled: hẳn là yêu vk thương con , what ?... → 0
# Line 8578 | Labeled: @Hien Nguyen 95 thua... → 1
# Line 8579 | Labeled: Đội ơn em .... → 0
# Line 8580 | Labeled: @Donal... → 4
# Line 8581 | Labeled: @Tran Hong 🖤🖤... → 4
# 💾 Checkpoint saved 5 comments (Total: 8580)
# Line 8582 | Labeled: Đã bảo ko bỏ vk mà con ny nó ko nge... → 1
# Line 8583 | Labeled: 😂😂😂... → 0
# Line 8584 | Labeled: khi bạn thích ăn phở và ko muốn bỏ cơm... → 4
# Line 8585 | Labeled: Chắc bà vợ mát lòng mát dạ lắm đây... → 0
# Line 8586 | Labeled: tính ra a ta chung tinh và yêu vợ, thả ảnh ra.... ... → 0
# 💾 Checkpoint saved 5 comments (Total: 8585)
# Line 8587 | Labeled: @cẫm Tú 🙄🙄🙄🙄🙏... → 4
# Line 8588 | Labeled: Mấy c.e định làm bé 3 thì nên rút kinh nghiệm nhé😂... → 0
# Line 8589 | Labeled: sao đời giờ chuyện gì cũng có thể sẩy ra hết vậy ớ... → 3
# Line 8590 | Labeled: vi khuẩn đã nói: hẹn hò không có nghĩa là yêu nhau... → 4
# Line 8591 | Labeled: Mấy e ba bi tờ ry có ý định làm chính thất chắc cũ... → 3
# 💾 Checkpoint saved 5 comments (Total: 8590)
# Line 8592 | Labeled: Ngoại tình là do nghiệp nhé.😅
# Đấy, ae tụi tôi đã c... → 0
# Line 8593 | Labeled: Tự hào về anh 😆... → 0
# Line 8594 | Labeled: a đã bảo rồi . chủ cặp thôi cứ ép a... → 1
# Line 8595 | Labeled: Haha eo cuối cùng tâm vẫn hướng về gia đình... → 0
# Line 8596 | Labeled: Có ng t3 mà vẫn yêu vk thương con 😏😏😏😏... → 0
# 💾 Checkpoint saved 5 comments (Total: 8595)
# Line 8597 | Labeled: đàn bà có đẹp cũng chỉ làm chậm tốc độ rút dao mà ... → 1
# Line 8598 | Labeled: Chà. Thấy cái vụ đa thê của tiền nhân khá hợp lý 🤒... → 4
# Line 8599 | Labeled: vụ mới hả mn🤔 hình như trc cũng có 1 vụ y như này ... → 4
# Line 8600 | Labeled: 😳😳😳😳😳😳... → 4
# Line 8601 | Labeled: 😂😂😂... → 0
# 💾 Checkpoint saved 5 comments (Total: 8600)
# Line 8602 | Labeled: Bản lĩnh đan ông là hải như vây... → 4
# Line 8603 | Labeled: Thật cảm động... → 0
# Line 8604 | Labeled: Hảo... → 0
# Line 8605 | Labeled: Phải cho bồ xem mới đc😅😅😅😅😅😅😅😅😅... → 0
# Line 8606 | Labeled: cái này có gọi chung tình với vk k ta😂... → 0
# 💾 Checkpoint saved 5 comments (Total: 8605)
# Line 8607 | Labeled: 😌 tốt... → 0
# Line 8608 | Labeled: vãi cả vẫn còn t.c với vk😂😂😂😂. buồn cuời thật😁... → 0
# Line 8609 | Labeled: Giỏi lắm anh chồng... → 0
# Line 8610 | Labeled: Thua🥺... → 2
# Line 8611 | Labeled: K rep ở lại lớpppp... → 1
# 💾 Checkpoint saved 5 comments (Total: 8610)
# Line 8612 | Labeled: nửa đời sau lên núi ở🤡... → 4
# Line 8613 | Labeled: chắc gặp thằng nhỏ hơn nó... chứ gặp mình chắc nó ... → 1
# Line 8614 | Labeled: đang táo bón cười phát phọt hết cả ra... → 0
# Line 8615 | Labeled: tim để gia đình mạnh khỏe 🍀... → 0
# Line 8616 | Labeled: parky nó vậy đấy... → 4
# 💾 Checkpoint saved 5 comments (Total: 8615)
# Line 8617 | Labeled: Tim để gặp nhiều may mắn... → 0
# Line 8618 | Labeled: ủa đâu ra 2 cái mũ vậy. khúc đầu nó có đội đâu nhỉ... → 0
# Line 8619 | Labeled: nhìn đểu là như nào vậy mọi người mấy giang hồ hay... → 1
# Line 8620 | Labeled: ko tim ở lại lớpp🥰... → 0
# Line 8621 | Labeled: tim gặp nhiều may mắn... → 0
# 💾 Checkpoint saved 5 comments (Total: 8620)
# Line 8622 | Labeled: “m thích cười không”... → 0
# Line 8623 | Labeled: ê lỡ cười to quá kh biết mấy ảnh có nghe thấy kh... → 0
# Line 8624 | Labeled: Chuyện thường ngày của Parky... → 4
# Line 8625 | Labeled: tưởng mình ngầu😂😂😂... → 0
# Line 8626 | Labeled: hướng nội đời còn lại... → 2
# 💾 Checkpoint saved 5 comments (Total: 8625)
# Line 8627 | Labeled: lại parky😌 ra đường toàn xưng bố... → 1
# Line 8628 | Labeled: bổ túc parky... → 4
# Line 8629 | Labeled: cái này chắc cali con... → 4
# Line 8630 | Labeled: nửa đời còn lại lên núi ở ẩn..... → 2
# Line 8631 | Labeled: uể ôi oai oai sí sí... → 0
# 💾 Checkpoint saved 5 comments (Total: 8630)
# Line 8632 | Labeled: @Bui Huu Lam Anh 💤💤  nhìn đểu tao ko 😂😂... → 1
# Line 8666 | Labeled: Xilloi vì đã cười:))... → 0
# 💾 Checkpoint saved 5 comments (Total: 8665)
# Line 8667 | Labeled: hướng nội hết phần đời còn lại=))... → 2
# Line 8668 | Labeled: @Wil definitely be done m nhìn đểu t à... → 1
# Line 8669 | Labeled: Đang ngầu... → 0
# Line 8670 | Labeled: Hướng nội tới già... → 2
# Line 8671 | Labeled: sorry bà nha xe tui hơi giãn á:))... → 0
# 💾 Checkpoint saved 5 comments (Total: 8670)
# Line 8672 | Labeled: Bản chất toc... → 4
# Line 8673 | Labeled: Các cháu tưởng thế là ngầu... → 4
# Line 8674 | Labeled: Ra đường nể mỗi 3 anh này🤣🤣🤣🤣... → 0
# Line 8675 | Labeled: lần sau đi đường nhắm mắt cho lành😇... → 3
# Line 8676 | Labeled: Có được cộng điểm thi không nhỉ🤡... → 3
# 💾 Checkpoint saved 5 comments (Total: 8675)
# Line 8677 | Labeled: @Lý Hiếu báo thủ bị nghiệp quật... → 1
# Line 8678 | Labeled: Dân bổ túc là nó phải thế 😂😂😂... → 0
# Line 8679 | Labeled: wow ngầu r đó... → 0
# Line 8680 | Labeled: Hướng nội tới già... → 2
# Line 8681 | Labeled: Rồi lấy cái nón của ngta chi vậy... → 4
# 💾 Checkpoint saved 5 comments (Total: 8680)
# Line 8682 | Labeled: ông trời có mắt😌😂... → 0
# Line 8683 | Labeled: t bị z chắc lên núi ở luôn á... → 2
# Line 8684 | Labeled: Nửa đời sau lên núi ở 😂... → 0
# Line 8685 | Labeled: cha mẹ đẻ nuôi vất vả tốn tiền tốn cơm... → 2
# Line 8686 | Labeled: @magtranii thich nhìn đểu bố m kh:))... → 1
# 💾 Checkpoint saved 5 comments (Total: 8685)
# Line 8687 | Labeled: Các em lại đi tìm bố😂... → 0
# Line 8688 | Labeled: ngại hộ=))... → 0
# Line 8689 | Labeled: vừa lòng Kao lắm 😂... → 0
# Line 8690 | Labeled: trong đây nhiều cali vãi😂😂😂, kh có nước😂... → 0
# Line 8691 | Labeled: nửa đời sau lên núi ở hết đời... → 4
# 💾 Checkpoint saved 5 comments (Total: 8690)
# Line 8692 | Labeled: Ba anh báo rất ngầu và đẹp trai🤡🤡... → 0
# Line 8693 | Labeled: "m thích nhìn đểu t kh"😂... → 0
# Line 8694 | Labeled: không có xe nên tống 3 hả🤡... → 1
# Line 8695 | Labeled: @sống nửa mắt😇 m thích nhìn đểu bố m k?... → 1
# Line 8696 | Labeled: nửa đời sau lên núi ở luon... → 2
# 💾 Checkpoint saved 5 comments (Total: 8695)
# Line 8697 | Labeled: @eccedentesiast @𝐓.𝐍𝐡à𝐧🥀 @☆ @phuongg @sinhungnho @... → 4
# Line 8698 | Labeled: Xử nhìn đểu là phụ, nhảy mũ là chính😂... → 0
# Line 8699 | Labeled: nửa đời sau lên núi ở @Ni... → 4
# Line 8700 | Labeled: mún thấy hình ảnh tụi nó lên đồn... → 4
# Line 8701 | Labeled: xem hết video xong k dám nhìn đểu 3 báo nữa chuyển... → 0
# 💾 Checkpoint saved 5 comments (Total: 8700)
# Line 8702 | Labeled: hôm trước 2 ae tôi vừa vào thăm trường cũ ra đang ... → 4
# Line 8703 | Labeled: “Bạn đã truyền tải cảm xúc qua từng nốt nhạc, thật... → 0
# Line 8704 | Labeled: vẫn cứ phải để con gương để xem thằng nhìn đểu :))... → 1
# Line 8705 | Labeled: Đúng mấy thg boy phố oai là giỏi 😅... → 1
# Line 8706 | Labeled: khái niệm nhìn đểu 😐... → 1
# 💾 Checkpoint saved 5 comments (Total: 8705)
# Line 8707 | Labeled: Rồi thanh niên kia cười báo thủ. Báo thủ lại đến k... → 1
# Line 8708 | Labeled: 😂😂😂😂😂sao xe cont đâu k hôn báo thủ troi... → 0
# Line 8709 | Labeled: Nên bổ túc thêm báo thủ này..... → 4
# Line 8710 | Labeled: Đau 1 nhục 1000000🤡... → 2
# Line 8711 | Labeled: parky tìm bố 😆😆... → 0
# 💾 Checkpoint saved 5 comments (Total: 8710)
# Line 8712 | Labeled: Xin lỗi mấy đứa vì bà đã cười 😁... → 0
# Line 8713 | Labeled: t mà ở đó là t cười cho ko ngớt đc đầu lên😂... → 0
# Line 8714 | Labeled: Đấy là lí do nó cầm lái chứ ko phải thk kia. Mik c... → 0
# Line 8715 | Labeled: rồi 2 cái mũ đâu ra vậy... → 4
# Line 8716 | Labeled: Sao toàn người Bắc nhỉ ?... → 4
# 💾 Checkpoint saved 5 comments (Total: 8715)
# Line 8717 | Labeled: Nói kp phân biệt chứ miền bắc hay có kiểu này 😂... → 4
# Line 8718 | Labeled: đang ngầu mà ô 😭... → 0
# Line 8719 | Labeled: Oai lắm... → 4
# Line 8720 | Labeled: bản chất pk.... → 4
# Line 8721 | Labeled: Mấy cháu h nghe nguy hiễm quá... → 3
# 💾 Checkpoint saved 5 comments (Total: 8720)
# Line 8722 | Labeled: Vừa lòng hết biết😂😂... → 0
# Line 8723 | Labeled: đủ wow chưa🤡🤡... → 0
# Line 8724 | Labeled: mắc cỡ quá chú... → 2
# Line 8725 | Labeled: Mắc cở☺️... → 0
# Line 8726 | Labeled: lúc đó em tưởng z là ngầu... → 0
# 💾 Checkpoint saved 5 comments (Total: 8725)
# Line 8727 | Labeled: Tam thái tử ở đâu đây... → 4
# Line 8728 | Labeled: cười chết=))))... → 0
# Line 8729 | Labeled: tao thích đấy... → 0
# Line 8730 | Labeled: Người miền núi chất... → 0
# Line 8731 | Labeled: Nửa đời sau chắc ko dám gặp ai 🤡... → 2
# 💾 Checkpoint saved 5 comments (Total: 8730)
# Line 8732 | Labeled: oai vậy à :))... → 0
# Line 8733 | Labeled: diễn hài à:))... → 0
# Line 8734 | Labeled: người cười trước mấy phút sau người cười lại... → 0
# Line 8735 | Labeled: mắc ngầu mà hổng đựt... → 1
# Line 8736 | Labeled: ngại vô cùng😍... → 0
# 💾 Checkpoint saved 5 comments (Total: 8735)
# Line 8737 | Labeled: đau1% nhục99%... → 2
# Line 8775 | Labeled: rồi lên núi ở luôn🥰... → 0
# Line 8776 | Labeled: hướng nội hết phần đời còn lại 😭... → 2
# 💾 Checkpoint saved 5 comments (Total: 8775)
# Line 8777 | Labeled: tưởng v là ngầu... → 4
# Line 8778 | Labeled: chịu rồi 😆... → 0
# Line 8779 | Labeled: nửa đời về sau lên núi ở... → 4
# Line 8780 | Labeled: t cười mất rồi t ác quá😞... → 0
# Line 8781 | Labeled: đang ăn mì mà xem đc video này khiến cộng mì của t... → 2
# 💾 Checkpoint saved 5 comments (Total: 8780)
# Line 8782 | Labeled: Chưa lên phường lần nào là chưa biết... → 4
# Line 8783 | Labeled: đi kiếm con chứ ạ... → 4
# Line 8784 | Labeled: núi bắt nạt dân bản à😂... → 1
# Line 8785 | Labeled: có thể là lên núi ở luôn... → 2
# Line 8786 | Labeled: Hướng nội hết phần đời con lại... → 2
# 💾 Checkpoint saved 5 comments (Total: 8785)
# Line 8787 | Labeled: Ghép kìa khúc đầu không đội mũ, khúc sau thì có mũ... → 0
# Line 8788 | Labeled: Giữ zay sao 😆😆... → 0
# Line 8789 | Labeled: mắc cỡ quá trời 🤣... → 0
# Line 8790 | Labeled: đội 10 cái quần... → 1
# Line 8791 | Labeled: các cụ có câu, ngầu chưa được 3 giây 🙏😭😭... → 2
# 💾 Checkpoint saved 5 comments (Total: 8790)
# Line 8792 | Labeled: Đúng bản chất parky... → 4
# Line 8793 | Labeled: Hướng nội suốt cuộc đời còn lại😇... → 2
# Line 8794 | Labeled: chưa nắng đi ra đường không đội nón bảo hiểm nên m... → 4
# Line 8795 | Labeled: Nhân lực thợ hồ😁... → 4
# Line 8796 | Labeled: dừa lòng t dữ lắm🥰🥰... → 0
# 💾 Checkpoint saved 5 comments (Total: 8795)
# Line 8797 | Labeled: "lúc đó cháu tưởng v là ngầu"😂... → 0
# Line 8798 | Labeled: mong anh sẽ không hỏi bố của tất cả người xem... → 3
# Line 8799 | Labeled: Cả đời còn lại ở dưới biển 😭... → 2
# Line 8800 | Labeled: gặp tui là tui lên núi ở luôn😂... → 0
# Line 8801 | Labeled: 😅😅😅vừa lòng tôi... → 0
# 💾 Checkpoint saved 5 comments (Total: 8800)
# Line 8802 | Labeled: con gái thời nay toàn think con trai kiểu như vậy... → 4
# Line 8803 | Labeled: Xóm t có 1 đống giống z lun😇... → 0
# Line 8804 | Labeled: mày biết bố mày là ai không 🤣🤣🤣... → 1
# Line 8805 | Labeled: Tính ngầu ngầu nhm ôg trời hong chô-)... → 0
# Line 8806 | Labeled: Lên núi chưa chắc hết quê 😂... → 4
# 💾 Checkpoint saved 5 comments (Total: 8805)
# Line 8807 | Labeled: đợt này rất thích like cmt của nKiiki... → 0
# Line 8808 | Labeled: Ông kia chắc quay mặt cười🗿... → 1
# Line 8809 | Labeled: luật hoa quả ko chừa 1 ai... → 1
# Line 8810 | Labeled: ntn phải đc 10₫ vùng miền... → 1
# Line 8811 | Labeled: Vào nam nè mấy a... → 4
# 💾 Checkpoint saved 5 comments (Total: 8810)
# Line 8812 | Labeled: nó lấy cái nón luôn hả 🤣🤣🤣... → 0
# Line 8813 | Labeled: t cười 10 năm... → 0
# Line 8814 | Labeled: tưởng thế ngầu 😂😂... → 0
# Line 8815 | Labeled: Xe hơi chiềng :)))... → 0
# Line 8816 | Labeled: Thể hiện... → 4
# 💾 Checkpoint saved 5 comments (Total: 8815)
# Line 8817 | Labeled: sinh ra trong mn là ổn lắm ròi... → 0
# Line 8818 | Labeled: xinloi vì đã cười... → 4
# Line 8819 | Labeled: có thể lên núi ở luôn đc….... → 4
# Line 8820 | Labeled: Tưởng thế là ngầu... → 4
# Line 8821 | Labeled: cho e nó ngầu tí... → 0
# 💾 Checkpoint saved 5 comments (Total: 8820)
# Line 8822 | Labeled: Trên bản hả... → 4
# Line 8823 | Labeled: Ngầu giữ chưa 😂... → 0
# Line 8824 | Labeled: sắp ngầu rồi mà... → 0
# Line 8825 | Labeled: xinh loi nha toi lo cuoi🤭😁... → 0
# Line 8826 | Labeled: Chắc gặp tôi tôi nhìn đẹp lại luôn... → 0
# 💾 Checkpoint saved 5 comments (Total: 8825)
# Line 8827 | Labeled: Để ảnh ngầu... → 0
# Line 8828 | Labeled: biết bố chưa 🤣... → 0
# Line 8829 | Labeled: đag đi thấy thk giống bố:)... → 0
# Line 8830 | Labeled: ai cười... → 4
# Line 8831 | Labeled: kkk... → 0
# 💾 Checkpoint saved 5 comments (Total: 8830)
# Line 8832 | Labeled: đang ngầu... → 0
# Line 8833 | Labeled: có cài vd thôi mà t cười nãy h... → 0
# Line 8834 | Labeled: nửa đời sau lên núi ở... → 4
# Line 8835 | Labeled: luật hoa quả không chừa 1 ai 🤣... → 0
# Line 8836 | Labeled: Ở sông mã mình nè ☺️... → 0
# 💾 Checkpoint saved 5 comments (Total: 8835)
# Line 8837 | Labeled: Chưa kịp ngầu mà🥺... → 2
# Line 8838 | Labeled: Từ ngày hôm đó không ai thấy anh xuống phố nữa:))... → 4
# Line 8839 | Labeled: quê là quê chúng mình 😂😂😂😂... → 0
# Line 8840 | Labeled: Khét lẹt😂... → 0
# Line 8841 | Labeled: Ở đó mà có thêm vài em gái nữa thì nửa đời còn lại... → 0
# 💾 Checkpoint saved 5 comments (Total: 8840)
# Line 8842 | Labeled: Video ghép cũng lừa được bao người mn để Ý xem 3 ... → 1
# Line 8843 | Labeled: quê là quê chúng mình 😆... → 0
# Line 8844 | Labeled: Mình nhìn cười đk ko... → 0
# Line 8845 | Labeled: Dạ em nhìn xịn ạ 😢... → 2
# Line 8846 | Labeled: oách nhờ😂😂😂... → 0
# 💾 Checkpoint saved 5 comments (Total: 8845)
# Line 8847 | Labeled: chắc giờ ra đường phải cất mắt đi😂😂... → 0
# Line 8848 | Labeled: hả dạ... → 4
# Line 8849 | Labeled: hướng nội hết phần đời còn lại :))... → 2
# Line 8850 | Labeled: bố nó làm to lắm....ở khu vực đó không ai giám đụn... → 1
# Line 8851 | Labeled: phim sét karaoke gia đình cha mẹ ace parky... → 4
# 💾 Checkpoint saved 5 comments (Total: 8850)
# Line 8852 | Labeled: uii đang ăn mà cười phọt hết cơm ra mâm... → 0
# Line 8853 | Labeled: ngầu chưa kịp 3s 😂... → 0
# Line 8854 | Labeled: đang ngầu 😂... → 0
# Line 8855 | Labeled: Rep... → 4
# Line 8856 | Labeled: khoe xăm à... → 1
# 💾 Checkpoint saved 5 comments (Total: 8855)
# Line 8857 | Labeled: sợ quá sợ quá 😅😅😅😅... → 3
# Line 8858 | Labeled: 1 điều nhịn 9999 điều lành... → 4
# Line 8859 | Labeled: T xem t còn thấy bcuoi... → 0
# Line 8860 | Labeled: thắc mắc lúc xuống xe kg nón lúc quay lại xe thì 2... → 4
# Line 8861 | Labeled: đang ngầu mà trờii😭😭... → 0
# 💾 Checkpoint saved 5 comments (Total: 8860)
# Line 8862 | Labeled: Lóc chóc 😅... → 0
# Line 8863 | Labeled: Tiểu sử t... → 4
# Line 8864 | Labeled: Khi giao xe vào tay thằng k bt đi xe :... → 1
# Line 8865 | Labeled: =)))))))) thuii t cười được chưa... → 0
# Line 8866 | Labeled: nhân quả... → 4
# 💾 Checkpoint saved 5 comments (Total: 8865)
# Line 8867 | Labeled: xin chúc mừng... → 0
# Line 8868 | Labeled: hướng nội hết phần đời còn lại 🤭... → 2
# Line 8869 | Labeled: Lúc dừng lại ko có đội nón lúc chạy thì đội nón... → 4
# Line 8870 | Labeled: t đang khóc mà lướt trúng vid☺️... → 2
# Line 8871 | Labeled: Xin lỗi vì cười ko ngậm đc mồm... → 0
# 💾 Checkpoint saved 5 comments (Total: 8870)
# Line 8872 | Labeled: Oai... → 4
# Line 8873 | Labeled: thg xe điện🤡... → 1
# Line 8874 | Labeled: mình còn nhớ hồi mới vào lớp 10
# bị một cj hẹn ở cổ... → 2
# Line 8875 | Labeled: hướng nội hết nữa đời sau... → 2
# Line 8876 | Labeled: đúng... → 4
# 💾 Checkpoint saved 5 comments (Total: 8875)
# Line 8877 | Labeled: ý là nhìn tụi nó hơi bị hài luôn á... → 0
# Line 8878 | Labeled: Quê là quê chúng mình t cười sảng 😂😂... → 0
# Line 8879 | Labeled: ảnh đang ngầu mà 🤡... → 0
# Line 8880 | Labeled: sao ko hỏi t. Ta. Phải chi hỏiaf đỡ bị té quê r.... → 2
# Line 8881 | Labeled: t cười đến ch3t 🥰... → 0
# 💾 Checkpoint saved 5 comments (Total: 8880)
# Line 8882 | Labeled: Sao cảnh đầu k đội mũ . Cảnh sau lại có mũ nhỉ :))... → 0
# Line 8883 | Labeled: kk... → 4
# ...
# 💾 Checkpoint saved 5 comments (Total: 12435)
# Line 12437 | Labeled: sao chúng nó ko gặp t nhỉ... → 2
# Line 12438 | Labeled: Dia bilang apa we😭... → 2
# Line 12439 | Labeled: hướng nội hết phần đời còn lại... → 2
# Line 12440 | Labeled: 😁😁😁... → 0
# Line 12441 | Labeled: @húi @Như @🪱 ☺️... → 0
# 💾 Checkpoint saved 5 comments (Total: 12440)
# Line 12442 | Labeled: @🗣 : SAY DRAKE !!! 💀 @tntt041210 @mít ướt khóc nhè... → 0
# Line 12443 | Labeled: 😳😳😳Hả... → 4
# Line 12444 | Labeled: @tf @michelin tương lai @𝜗𝜚thu haa @my dog👩🏻‍🦰 @th... → 1
# Line 12445 | Labeled: Chưa thấy( tai quàn) chưa đổ lệ... → 2
# Line 12446 | Labeled: 🤣🤣🤣... → 0
# 💾 Checkpoint saved 5 comments (Total: 12445)
# Line 12447 | Labeled: @nguoihaysuy😞... → 2
# Line 12448 | Labeled: 🤣🤣... → 0
# Line 12449 | Labeled: Nó đi tìm bố mà để no đi đi... → 2
# Line 12450 | Labeled: 🥵🥵... → 0
# Line 12451 | Labeled: 😏😏😏😏... → 0
# 💾 Checkpoint saved 5 comments (Total: 12450)
# Line 12452 | Labeled: 😂😂... → 0
# Line 12453 | Labeled: 🤣🤣🤣... → 0
# Line 12454 | Labeled: @_ytuh.ihci_td boy phố chính hiệu :)))... → 0
# Line 12455 | Labeled: 😂😂😂... → 0
# Line 12456 | Labeled: 😂😂😂... → 0
# 💾 Checkpoint saved 5 comments (Total: 12455)
# Line 12457 | Labeled: @yeuanhlamaimai🍇... → 4
# Line 12458 | Labeled: khuyên thật lên núi ở đi 😇... → 0
# Line 12459 | Labeled: @Trần VyVy ☺... → 0
# Line 12460 | Labeled: núi... → 4
# Line 12461 | Labeled: ôi còn sông quê... → 2
# 💾 Checkpoint saved 5 comments (Total: 12460)
# Line 12462 | Labeled: 😂... → 0
# Line 12463 | Labeled: 🤣... → 0
# Line 12464 | Labeled: Hướng nội suốt phần đời còn lại😭... → 2
# Line 12465 | Labeled: @hoàng anh... → 4
# Line 12466 | Labeled: Bị bắt chưa... → 3
# 💾 Checkpoint saved 5 comments (Total: 12465)
# Line 12467 | Labeled: Đúng là gậy ông đập lưng ông🤣... → 0
# Line 12468 | Labeled: 😂😂😂... → 0
# Line 12469 | Labeled: Boy núi à... → 4
# Line 12470 | Labeled: 😂😂😂... → 0
# Line 12471 | Labeled: VN2025... → 4
# 💾 Checkpoint saved 5 comments (Total: 12470)
# Line 12472 | Labeled: Cho chừa parki😂... → 1
# Line 12473 | Labeled: lên phường... → 4
# Line 12474 | Labeled: 😂😂😂... → 0
# Line 12475 | Labeled: 🥰🥰🥰... → 0
# Line 12476 | Labeled: thấy cũng tội mà thôi cũng kệ... → 2
# 💾 Checkpoint saved 5 comments (Total: 12475)
# Line 12477 | Labeled: peter ko nghe lời... → 4
# Line 12478 | Labeled: 😏😏😏... → 0
# Line 12479 | Labeled: 👏👏👏... → 0
# Line 12480 | Labeled: 😳😳😳... → 4
# Line 12481 | Labeled: Cười rụng răng 😂😂... → 0
# 💾 Checkpoint saved 5 comments (Total: 12480)
# Line 12482 | Labeled: 😂😂😂😂... → 0
# Line 12483 | Labeled: hk quê , hk quê nhá... → 2
# Line 12484 | Labeled: 😂😂😂... → 0
# Line 12485 | Labeled: VN hay tò mò nhìn người khác chằm chằm 😂😅... → 0
# Line 12486 | Labeled: Đang ngầu mà đồng đội lại bóp 😂... → 0
# 💾 Checkpoint saved 5 comments (Total: 12485)
# Line 12487 | Labeled: 🥰🥰🥰😂😂😂😂😂😂😊😊😊🤣🤣🤣🤣🤣🤣🤣🤣🤣😳😳😳😳😳😳😁😁😁🤣🤣🤣😊😊😊😂😂😂😂😂😂🥰🥰🥰😑😬🙄😯😦... → 0
# Line 12488 | Labeled: ước đc gặp 3 anh này 🥰... → 0
# Line 12489 | Labeled: Nên lấy cái quần xì đội lên đầu 🤣🤣🤣... → 0
# Line 12490 | Labeled: 😂😂... → 0
# Line 12491 | Labeled: 🤣... → 0
# 💾 Checkpoint saved 5 comments (Total: 12490)
# Line 12492 | Labeled: thích nhìn đểu chứ 😝... → 1
# Line 12493 | Labeled: VN2025... → 4
# Line 12494 | Labeled: @:)))))))... → 0
# Line 12495 | Labeled: 😂😂😂... → 0
# Line 12496 | Labeled: @lunn... → 4
# 💾 Checkpoint saved 5 comments (Total: 12495)
# Line 12497 | Labeled: 😂😂😂... → 0
# Line 12498 | Labeled: @B_ngocanhh_06 @ℍ𝕒𝕗𝕫 ℕ𝕙𝕙𝕛𝕖 燕阮 ²⁵⁰³... → 4
# Line 12499 | Labeled: quê là quê chúng mình quê nhiều 😂... → 0
# Line 12500 | Labeled: Đau 1 quê 10... → 2
# Line 12501 | Labeled: 🤣... → 0
# 💾 Checkpoint saved 5 comments (Total: 12500)
# Line 12502 | Labeled: Đứng lên và ns với xe: m thích té đểu kh... → 1
# Line 12503 | Labeled: @nho anh. @Xe đạp hết điện @1008. @ByeBye_Kitty @k... → 4
# Line 12504 | Labeled: hồi đó nó tưởng thế là oai🤭... → 0
# Line 12505 | Labeled: 😂 vừa lòng tao lắm... → 0
# Line 12506 | Labeled: hết ngầu 🙃... → 4
# 💾 Checkpoint saved 5 comments (Total: 12505)
# Line 12507 | Labeled: @nguyen... → 4
# Line 12508 | Labeled: @Gàa🐣🐥 @kimchau @ko có tên... → 4
# Line 12509 | Labeled: 😂😂😂... → 0
# Line 12510 | Labeled: chắc mai lướt xong ngậm ngùi lướt qua vì quá nhục... → 2
# Line 12511 | Labeled: từ đó hướng nội đến cuối đời... → 2
# 💾 Checkpoint saved 5 comments (Total: 12510)
# Line 12512 | Labeled: @duy 5k(TT❤️) @VUA LOÀI CHUỘT 🐀 @vua loài báo🐆 @gi... → 0
# Line 12513 | Labeled: có vậy mà t cười nãy giờ 😇... → 0
# Line 12514 | Labeled: 😂😂😂😂... → 0
# Line 12515 | Labeled: 😂😂😂... → 0
# Line 12516 | Labeled: ghét máy tk mà kiểu chơi băng nhóm mà hay đi dựa h... → 1
# 💾 Checkpoint saved 5 comments (Total: 12515)
# Line 12517 | Labeled: 🤣🤣🤣... → 0
# Line 12518 | Labeled: 😂😂😂... → 0
# Line 12519 | Labeled: cười xỉu😂😂... → 0
# Line 12520 | Labeled: Sau hướng nội tới già... → 2
# Line 12521 | Labeled: 😂😂😂... → 0
# 💾 Checkpoint saved 5 comments (Total: 12520)
# Line 12522 | Labeled: @thích gà rán hài vãi... → 0
# Line 12523 | Labeled: @𓆝Kit.kat𐙚 @i miss.⚡️🐑 @B.an hạt nhài... → 4
# Line 12524 | Labeled: 😅😅😅... → 0
# Line 12525 | Labeled: @kieu nha... → 4
# Line 12526 | Labeled: Quê là quê là quê... → 4
# 💾 Checkpoint saved 5 comments (Total: 12525)
# Line 12527 | Labeled: =)))... → 0
# Line 12528 | Labeled: @Phúc👹... → 4
# Line 12529 | Labeled: Đừng nói nó là bổ túc bổ túc ko có loại này... → 1
# Line 12530 | Labeled: gặp tụi t chắc tụi nó giả bộ xĩu cho đỡ quê quá:))... → 0
# Line 12531 | Labeled: bố thích... → 0
# 💾 Checkpoint saved 5 comments (Total: 12530)
# Line 12532 | Labeled: oách phết tý thì hỏi thăm bác sĩ 🤣🤣🤣... → 0
# Line 12533 | Labeled: @cánh cụt biết bay😛... → 0
# Line 12534 | Labeled: @Sữa🧋... → 4
# Line 12535 | Labeled: 🤣🤣🤣... → 0
# Line 12536 | Labeled: hướng ngoại thành hướng nội luôn 😂... → 0
# 💾 Checkpoint saved 5 comments (Total: 12535)
# Line 12537 | Labeled: 😂😂😂... → 0
# Line 12538 | Labeled: vùng sâu vùng xa😊... → 0
# Line 12539 | Labeled: @duonggggcuteeeee thích nhìn đểu k... → 1
# Line 12540 | Labeled: @nqocw.dyiu duy ai đồ... → 1
# Line 12541 | Labeled: tay lai yeu8... → 4
# 💾 Checkpoint saved 5 comments (Total: 12540)
# Line 12542 | Labeled: Có thể hướng nội cả kiếp sau... → 2
# Line 12543 | Labeled: cậu xỉ đs 😅... → 1
# Line 12544 | Labeled: @khanifxi... → 4
# Line 12545 | Labeled: @ieu quỳnh chi >< @talogdevs * cụp cái pha xuống *... → 4
# Line 12546 | Labeled: Sợ mấy ông choai choai này lắm😂... → 3
# 💾 Checkpoint saved 5 comments (Total: 12545)
# Line 12547 | Labeled: nhìn đểu là nhìn như nào vậy ae. để e còn tránh... → 4
# Line 12548 | Labeled: @người già neo đơnn 🐍... → 4
# Line 12549 | Labeled: Quả táo không chừa 1 ai :)))... → 0
# Line 12550 | Labeled: 😂😂😂😂😂😂... → 0
# Line 12551 | Labeled: @ko có tên :))... → 0
# 💾 Checkpoint saved 5 comments (Total: 12550)
# Line 12552 | Labeled: @yennhi 😂... → 0
# Line 12553 | Labeled: 😳... → 4
# Line 12554 | Labeled: thằng bị chửi cười rớt pi tơ 😂... → 0
# Line 12555 | Labeled: 😂😂😂... → 0
# Line 12556 | Labeled: 🥰🥰🥰... → 0
# 💾 Checkpoint saved 5 comments (Total: 12555)
# Line 12557 | Labeled: 🤣🤣🤣🤣... → 0
# Line 12558 | Labeled: @Tiên♡... → 4
# Line 12559 | Labeled: Mong rằng các e sẽ gặp người tốt tính hơn❤️❤️... → 0
# Line 12560 | Labeled: hảo Hán... → 0
# Line 12561 | Labeled: Cỡ này phải cộng điểm vùng miền tuyệt đối 🤣... → 0
# 💾 Checkpoint saved 5 comments (Total: 12560)
# Line 12562 | Labeled: 😂😂😂... → 0
# Line 12563 | Labeled: 😁😁😁... → 0
# Line 12564 | Labeled: T cười xốn lè luôn😇... → 0
# Line 12565 | Labeled: quê liền... → 4
# Line 12566 | Labeled: Quê là quê :))... → 0
# 💾 Checkpoint saved 5 comments (Total: 12565)
# Line 12567 | Labeled: nửa đời sau lên núi sống🤣... → 0
# Line 12568 | Labeled: @Người Tây gốc Cây 💋 hài😂... → 0
# Line 12569 | Labeled: @_beebili.210 😳... → 4
# Line 12570 | Labeled: Đoạn cắt là đoạn nó quay lại hỏi hang thích cuoi k... → 0
# Line 12571 | Labeled: gặp t ở đó chắc cười banh xác 🤣... → 0
# 💾 Checkpoint saved 5 comments (Total: 12570)
# Line 12572 | Labeled: 😁😁😁😁... → 0
# Line 12573 | Labeled: @n. @tktt!... → 4
# Line 12574 | Labeled: Clip kiểu này thì lại khổ cho gia đình lo tiền nộp... → 2
# Line 12575 | Labeled: 😂... → 0
# Line 12576 | Labeled: @Thắng Phan... → 4
# 💾 Checkpoint saved 5 comments (Total: 12575)
# Line 12577 | Labeled: 😂vừa lòng t lắm... → 0
# Line 12578 | Labeled: @Nqoc Hânn🧸 😂... → 0
# Line 12579 | Labeled: v còn nhẹ... → 4
# Line 12580 | Labeled: oách xà lách vô cùng 🤡... → 0
# Line 12581 | Labeled: 🤣🤣🤣🤣🤣... → 0
# 💾 Checkpoint saved 5 comments (Total: 12580)
# Line 12582 | Labeled: sao mình chưa bao giờ gặp người như z ta... → 2
# Line 12583 | Labeled: 🤣🤣🤣... → 0
# Line 12584 | Labeled: @Tuan Khanh 💸 m thích nhìn đểu ko... → 1
# Line 12585 | Labeled: Thích nhìn bố k 😂... → 0
# Line 12586 | Labeled: @𝒽𝓊𝓎ề𝓃𝓁ươ𝓃𝑔🌷... → 4
# 💾 Checkpoint saved 5 comments (Total: 12585)
# Line 12587 | Labeled: 😂... → 0
# Line 12588 | Labeled: 😁😁😁... → 0
# Line 12589 | Labeled: Ôi nam ky😂ơi😂... → 0
# Line 12590 | Labeled: @cuns... → 4
# Line 12591 | Labeled: @Vũ Duy Mạnh @Nguyễn Văn Huy... → 4
# 💾 Checkpoint saved 5 comments (Total: 12590)
# Line 12592 | Labeled: =))))))... → 0
# Line 12593 | Labeled: @Ha_bebe200🐝 quê chữ eeeee kéo dài😂... → 0
# Line 12594 | Labeled: 🗿🗿🗿... → 4
# Line 12595 | Labeled: 😂😂😂... → 0
# Line 12596 | Labeled: tộc hay nhỉ🗿... → 4
# 💾 Checkpoint saved 5 comments (Total: 12595)
# Line 12597 | Labeled: @Knguyeen🐢💤... → 4
# Line 12598 | Labeled: sr nha hơi lỗi... → 4
# Line 12599 | Labeled: :)... → 0
# Line 12600 | Labeled: ko dám quay đầu nhìn🥰... → 3
# Line 12601 | Labeled: rồi kiểu này gái chê hết 🤣... → 0
# 💾 Checkpoint saved 5 comments (Total: 12600)
# Line 12602 | Labeled: 😘😘😘... → 0
# Line 12603 | Labeled: Hướng nội hết phần đời còn lại... → 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 label_and_export_comments(csv_output_file, labeled_csv_output_file, checkpoint_interval=5)
#
# Cell In[4], line 34, in label_and_export_comments(input_csv_file, output_csv_file, checkpoint_interval)
#      31     continue
#      33 # Gán nhãn cảm xúc
# ---> 34 emotion_label = label_emotion_with_lmstudio(text)
#      35 labeled_comment = {
#      36     'line_number': line_number,
#      37     'text': text,
#      38     'emotion_label': emotion_label
#      39 }
#      41 batch.append(labeled_comment)
#
# Cell In[3], line 57, in label_emotion_with_lmstudio(text)
#      49 payload = {
#      50     "messages": [{"role": "user", "content": prompt}],
#      51     "temperature": 0.3,
#      52     "max_tokens": 1,
#      53     "stop": ["\n"]
#      54 }
#      56 # Gọi API LM Studio
# ---> 57 response = requests.post(
#      58     "http://localhost:1234/v1/chat/completions",
#      59     headers={'Content-Type': 'application/json'},
#      60     json=payload,
#      61     timeout=600
#      62 )
#      64 # Xử lý response
#      65 response.raise_for_status()
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\Illya\Workspace\4thYear\semester_2\IE403\DoAn\venv\lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File C:\laragon\bin\python\python-3.10\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File C:\laragon\bin\python\python-3.10\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File C:\laragon\bin\python\python-3.10\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File C:\laragon\bin\python\python-3.10\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:
